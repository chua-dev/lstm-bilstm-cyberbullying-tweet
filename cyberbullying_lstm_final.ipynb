# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import CountVectorizer
import re
import numpy as np

import plotly.graph_objs as go
from plotly.offline import iplot

# Emoji to strip emoji
import emoji #pip install emoji

# %% [markdown]
# # Data Import and Display

# %%
# Panda set max col width to none, so that all the text can be display
pd.set_option('display.max_colwidth', None)

df = pd.read_csv("cyberbullying_tweets.csv")
#df.style.set_properties(**{'text-align': 'right'}) # Align all text in columns to left
df.head(10)
# Out:
#                                                                                                                                      tweet_text  \
# 0                                                                                 In other words #katandandre, your food was crapilicious! #mkr
# 1                                                                  @gcarothers eek. i can't stand split keyboards. doesn't work well with MMOs.
# 2            @GlennF @Spacekatgal it is rather funny how all of us are so completely different, yet complement each other's skill sets so well.
# 3  @jukes303 The old oil cliche again. The US pays for every drop of oil they get from the ME on the open market just like every other country.
# 4                           Why is #aussietv so white? #MKR #theblock #ImACelebrityAU #today #sunrise #studio10 #Neighbours #WonderlandTen #etc
# 5        @onebrightlight i've been talking to 2 employees and i heard about a lot of the internal politics re: GG. it's enough to make me stay.
# 6                                       @Jason_Gio meh. :P  thanks for the heads up, but not too concerned about another angry dude on twitter.
# 7                                       @RudhoeEnglish This is an ISIS account pretending to be a Kurdish account.  Like Islam, it is all lies.
# 8           @Raja5aab @Quickieleaks Yes, the test of god is that good or bad or indifferent or weird or whatever, it all proves gods existence.
# 9                                                                               Karma. I hope it bites Kat on the butt. She is just nasty. #mkr
#
#   cyberbullying_type
# 0  not_cyberbullying
# 1  not_cyberbullying
# 2  not_cyberbullying
# 3  not_cyberbullying
# 4  not_cyberbullying
# 5  not_cyberbullying
# 6  not_cyberbullying
# 7  not_cyberbullying
# 8  not_cyberbullying
# 9  not_cyberbullying

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47693 entries, 0 to 47692
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_text          47693 non-null  object
#  1   cyberbullying_type  47693 non-null  object
# dtypes: object(2)
# memory usage: 745.3+ KB

# %% [markdown]
# ## Text Data Preprocessing For Data Exploration
# ### In this data exploration section,  I am going to
# 1. First, do some basic text cleaning using lowercase, regular expression and stopword.
# 2. Ultilize the powerful word cloud to visualize most appeared word both in all classes.
# 3. Getting highest frequency of unigram and bigram of each class use plot a graph.

# %%
# Regular Expression pattern of text cleaning pattern
# This REGEX pattern remove any @tagname from tweet, remove #hashtag !@#$%^&*: etc., remove website name like https:///www.fb.com
# But will remain all the A-Z a-z 0-9 character
TEXT_CLEANING_RE = "@\S+|https?:\S+|http?:\S|[^A-Za-z0-9]+"

# pip install wordcloud
# import word cloud to produce wordcloud on cleaned twitter text for data exploration
from wordcloud import STOPWORDS
STOPWORDS.update(['rt', 'mkr', 'didn', 'bc', 'n', 'm', 'im', 'll', 'y', 've', 'u', 'ur', 'don', 't', 's'])

# Function To preprocess the twitter text

# Lowercase all text
def lower(text):
    return text.lower()

# To clean the tweet with REGEX above
def clean_tweet_re(text):
    return re.sub(TEXT_CLEANING_RE, ' ', text)

def remove_stopwords(text):
    return " ".join([word for word in str(text).split() if word not in STOPWORDS])

# %%
# Create a copy of df for visualization
df_visual = df.copy()

df_visual['tweet_text'] = df_visual['tweet_text'].apply(lower)
df_visual['tweet_text'] = df_visual['tweet_text'].apply(clean_tweet_re)
df_visual['tweet_text'] = df_visual['tweet_text'].apply(remove_stopwords)


# Color Class for python printing, Making print more easy to read
class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

# Comparing Ori Tweet Text vs cleaned Tweet Text, Original black bold color vs Clean green bold color
for i in range(0, 10):
    original_text = df['tweet_text'].head(10)[i]
    cleaned_text = df_visual['tweet_text'].head(10)[i]
    comparision = f'{color.BOLD} {i}) {original_text} ==>> {color.GREEN} {color.BOLD} {cleaned_text} {color.END}\n'
    print(comparision)
# Out:
#  0) In other words #katandandre, your food was crapilicious! #mkr ==>>   words katandandre food crapilicious
#
#  1) @gcarothers eek. i can't stand split keyboards. doesn't work well with MMOs. ==>>   eek stand split keyboards doesn work well mmos
#
#  2) @GlennF @Spacekatgal it is rather funny how all of us are so completely different, yet complement each other's skill sets so well. ==>>   spacekatgal rather funny us completely different yet complement skill sets well
#
#  3) @jukes303 The old oil cliche again. The US pays for every drop of oil they get from the ME on the open market just like every other country. ==>>   old oil cliche us pays every drop oil open market every country
#
#  4) Why is #aussietv so white? #MKR #theblock #ImACelebrityAU #today #sunrise #studio10 #Neighbours #WonderlandTen #etc ==>>   aussietv white theblock imacelebrityau today sunrise studio10 neighbours wonderlandten etc
#
#  5) @onebrightlight i've been talking to 2 employees and i heard about a lot of the internal politics re: GG. it's enough to make me stay. ==>>   talking 2 employees heard lot internal politics re gg enough make stay
#
#  6) @Jason_Gio meh. :P  thanks for the heads up, but not too concerned about another angry dude on twitter. ==>>   meh p thanks heads concerned another angry dude twitter
#
#  7) @RudhoeEnglish This is an ISIS account pretending to be a Kurdish account.  Like Islam, it is all lies. ==>>   isis account pretending kurdish account islam lies
#
#  8) @Raja5aab @Quickieleaks Yes, the test of god is that good or bad or indifferent or weird or whatever, it all proves gods existence. ==>>   quickieleaks yes test god good bad indifferent weird whatever proves gods existence
#
#  9) Karma. I hope it bites Kat on the butt. She is just nasty. #mkr ==>>   karma hope bites kat butt nasty

# %%
# Create this function to get the highest count of unigram and bigrams

def get_highest_gram(corpus,ngram_range,n=None):
    vec = CountVectorizer(ngram_range=ngram_range,stop_words = STOPWORDS).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

# %% [markdown]
# # Data Exploration
# In this data exploration section, I am going to explore the most used word with wordcloud and bar plot table for each Class (Not Bullying, Gender, Etc)

# %% [markdown]
# ## Not Bullying Class Word Exploration

# %%
# Import word cloud to visualize highest count word with cloud display effect
from wordcloud import WordCloud

plt.figure(figsize=(20, 10)) #Setting figure size to better width
subset_notbully = df_visual[df_visual['cyberbullying_type'] == 'not_cyberbullying']
text_notbully = subset_notbully.tweet_text.values
cloud_notbully = WordCloud(background_color='black',colormap="Dark2",collocations=False,width=2000,height=1000).generate(" ".join(text_notbully))

plt.axis('off')
plt.title("Not Bully", fontsize=40)
plt.imshow(cloud_notbully)

# %%
# Pandas Series object do not have a iplot function
# This code is to use cufflinks to link plotly to pandas and add iplot used at below

import cufflinks as cf
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.11.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Get the unigrams, single word that appear most 
unigrams_notbully = get_highest_gram(text_notbully,(1,1),10)

# Get the bigrams, two word that appear most
bigrams_notbully = get_highest_gram(text_notbully,(2,2),10)

notbully_1 = pd.DataFrame(unigrams_notbully, columns = ['Text' , 'count'])
notbully_1.groupby('Text').sum()['count'].sort_values(ascending=True).iplot(kind='bar', yTitle='Count', linecolor='black',color='black', title='Top 10 Unigrams',orientation='h')

notbully_2 = pd.DataFrame(bigrams_notbully, columns = ['Text' , 'count'])
notbully_2.groupby('Text').sum()['count'].sort_values(ascending=True).iplot(kind='bar', yTitle='Count', linecolor='black',color='black', title='Top 10 Bigrams',orientation='h')
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_extraction\text.py:396: UserWarning:
#
# Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['aren', 'couldn', 'doesn', 'hadn', 'hasn', 'haven', 'isn', 'let', 'mustn', 're', 'shan', 'shouldn', 'wasn', 'weren', 'won', 'wouldn'] not in stop_words.
# <div>                            <div id="29b28e29-5afc-4c70-ab8d-8504c52d5c53" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("29b28e29-5afc-4c70-ab8d-8504c52d5c53")) {                    Plotly.newPlot(                        "29b28e29-5afc-4c70-ab8d-8504c52d5c53",                        [{"marker":{"color":"rgba(0, 0, 0, 0.6)","line":{"color":"rgba(0, 0, 0, 1.0)","width":1}},"name":"count","orientation":"h","text":"","x":[219,226,229,248,273,283,301,343,413,725],"y":["know","go","will","one","people","amp","kat","school","bully","bullying"],"type":"bar"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergeo"}],"scattergl":[ ...
# <div>                            <div id="bc094fb4-045f-4db8-bce6-e8233fedfac0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("bc094fb4-045f-4db8-bce6-e8233fedfac0")) {                    Plotly.newPlot(                        "bc094fb4-045f-4db8-bce6-e8233fedfac0",                        [{"marker":{"color":"rgba(0, 0, 0, 0.6)","line":{"color":"rgba(0, 0, 0, 1.0)","width":1}},"name":"count","orientation":"h","text":"","x":[26,28,31,31,31,35,52,55,68,147],"y":["di bully","right now","de bullying","high school","isso bullying","bullying se","amp andre","kat amp","gt gt","kat andre"],"type":"bar"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks": ...

# %% [markdown]
# ## Gender Class Word Exploration

# %%
plt.figure(figsize=(20,10)) 
subset1 = df_visual[df_visual['cyberbullying_type'] == 'gender']
text_gender = subset1.tweet_text.values
cloud1=WordCloud(background_color='black',colormap="Dark2",collocations=False,width=2000,height=1000).generate(" ".join(text_gender))

plt.axis('off')
plt.title("Gender",fontsize=40)
plt.imshow(cloud1)

# %%
# Get the unigrams, single word that appear most 
unigrams_gender = get_highest_gram(text_gender,(1,1),10)

# Get the bigrams, two word that appear most
bigrams_gender = get_highest_gram(text_gender,(2,2),10)

gender_1 = pd.DataFrame(unigrams_gender, columns = ['Text' , 'count'])
gender_1.groupby('Text').sum()['count'].sort_values(ascending=True).iplot(kind='bar', yTitle='Count', linecolor='black',color='black', title='Top 10 Unigrams',orientation='h')

gender_2 = pd.DataFrame(bigrams_gender, columns = ['Text' , 'count'])
gender_2.groupby('Text').sum()['count'].sort_values(ascending=True).iplot(kind='bar', yTitle='Count', linecolor='black',color='black', title='Top 10 Bigrams',orientation='h')
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_extraction\text.py:396: UserWarning:
#
# Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['aren', 'couldn', 'doesn', 'hadn', 'hasn', 'haven', 'isn', 'let', 'mustn', 're', 'shan', 'shouldn', 'wasn', 'weren', 'won', 'wouldn'] not in stop_words.
# <div>                            <div id="967133a9-0207-4617-85da-a6325419a8af" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("967133a9-0207-4617-85da-a6325419a8af")) {                    Plotly.newPlot(                        "967133a9-0207-4617-85da-a6325419a8af",                        [{"marker":{"color":"rgba(0, 0, 0, 0.6)","line":{"color":"rgba(0, 0, 0, 1.0)","width":1}},"name":"count","orientation":"h","text":"","x":[834,866,916,990,990,1008,1921,3456,3879,4298],"y":["female","bitch","women","call","sexist","people","joke","jokes","gay","rape"],"type":"bar"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergeo"}],"sca ...
# <div>                            <div id="1bf9a5c7-0bad-498f-b86c-1e0312f08c29" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("1bf9a5c7-0bad-498f-b86c-1e0312f08c29")) {                    Plotly.newPlot(                        "1bf9a5c7-0bad-498f-b86c-1e0312f08c29",                        [{"marker":{"color":"rgba(0, 0, 0, 0.6)","line":{"color":"rgba(0, 0, 0, 1.0)","width":1}},"name":"count","orientation":"h","text":"","x":[189,194,228,237,274,307,447,654,777,1476],"y":["prison rape","joke gay","gay people","rape gay","jokes gay","jokes rape","gay rape","gay jokes","rape joke","rape jokes"],"type":"bar"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0 ...

# %% [markdown]
# ## Age Bully Class Word Exploration

# %%
plt.figure(figsize=(20,10)) #Setting figure size to better width

subset_age = df_visual[df_visual['cyberbullying_type']=='age']
text_age = subset_age.tweet_text.values
cloud1=WordCloud(background_color='black',colormap="Dark2",collocations=False,width=2000,height=1000).generate(" ".join(text_age))

plt.axis('off')
plt.title("Age",fontsize=40)
plt.imshow(cloud1)

# %%
# Get the unigrams, single word that appear most 
unigrams_age = get_highest_gram(text_age,(1,1),10)

# Get the bigrams, two word that appear most
bigrams_age = get_highest_gram(text_age,(2,2),10)

age_1 = pd.DataFrame(unigrams_age, columns = ['Text' , 'count'])
age_1.groupby('Text').sum()['count'].sort_values(ascending=True).iplot(kind='bar', yTitle='Count', linecolor='black',color='black', title='Top 10 Unigrams',orientation='h')

age_2 = pd.DataFrame(bigrams_age, columns = ['Text' , 'count'])
age_2.groupby('Text').sum()['count'].sort_values(ascending=True).iplot(kind='bar', yTitle='Count', linecolor='black',color='black', title='Top 10 Bigrams',orientation='h')
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_extraction\text.py:396: UserWarning:
#
# Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['aren', 'couldn', 'doesn', 'hadn', 'hasn', 'haven', 'isn', 'let', 'mustn', 're', 'shan', 'shouldn', 'wasn', 'weren', 'won', 'wouldn'] not in stop_words.
# <div>                            <div id="fd125400-586d-4aa1-b695-41b4963d2c84" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("fd125400-586d-4aa1-b695-41b4963d2c84")) {                    Plotly.newPlot(                        "fd125400-586d-4aa1-b695-41b4963d2c84",                        [{"marker":{"color":"rgba(0, 0, 0, 0.6)","line":{"color":"rgba(0, 0, 0, 1.0)","width":1}},"name":"count","orientation":"h","text":"","x":[912,934,955,1639,2341,2357,2756,4392,5082,8302],"y":["now","people","one","bullies","girls","girl","bully","bullied","high","school"],"type":"bar"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergeo"}], ...
# <div>                            <div id="a972a173-fa73-49dd-9f1f-808f75ef59c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("a972a173-fa73-49dd-9f1f-808f75ef59c5")) {                    Plotly.newPlot(                        "a972a173-fa73-49dd-9f1f-808f75ef59c5",                        [{"marker":{"color":"rgba(0, 0, 0, 0.6)","line":{"color":"rgba(0, 0, 0, 1.0)","width":1}},"name":"count","orientation":"h","text":"","x":[237,245,375,442,602,659,780,802,1344,4645],"y":["school bullied","girls high","got bullied","school bullies","middle school","girl bullied","school bully","girls bullied","bullied high","high school"],"type":"bar"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker ...

# %% [markdown]
# # Data Preprocessing For Train In Deep Learning model
# Note that the Data Frame `df_visual` is preprocessed (using different method) and are meant to use in word cloud data exploration only. Now I will switch back to main Data Frame `df` to do different preprocessing that will be used to fit into Deep Learning Model to train for the cyberbullying classification problems.

# %%
df.head()
# Out:
#                                                                                                                                      tweet_text  \
# 0                                                                                 In other words #katandandre, your food was crapilicious! #mkr
# 1                                                                  @gcarothers eek. i can't stand split keyboards. doesn't work well with MMOs.
# 2            @GlennF @Spacekatgal it is rather funny how all of us are so completely different, yet complement each other's skill sets so well.
# 3  @jukes303 The old oil cliche again. The US pays for every drop of oil they get from the ME on the open market just like every other country.
# 4                           Why is #aussietv so white? #MKR #theblock #ImACelebrityAU #today #sunrise #studio10 #Neighbours #WonderlandTen #etc
#
#   cyberbullying_type
# 0  not_cyberbullying
# 1  not_cyberbullying
# 2  not_cyberbullying
# 3  not_cyberbullying
# 4  not_cyberbullying

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47693 entries, 0 to 47692
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_text          47693 non-null  object
#  1   cyberbullying_type  47693 non-null  object
# dtypes: object(2)
# memory usage: 745.3+ KB

# %%
# Rename columns into shorter words for easier references
df = df.rename(columns={'tweet_text': 'text', 'cyberbullying_type': 'bully_type'})

# %%
# df.duplicated function will take the row that have excalty same value across all columns as true
df.duplicated().sum()
# Out:
# 46

# %%
# This line will drop the duplicated 46 rows
df = df[~df.duplicated()]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47647 entries, 0 to 47692
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   text        47647 non-null  object
#  1   bully_type  47647 non-null  object
# dtypes: object(2)
# memory usage: 1.1+ MB

# %% [markdown]
# After dropping the 46 duplicated rows, the total rows had turn from `47693` to `47647`

# %%
# Now we want to check if the data class is balance
df['bully_type'].value_counts()
# Out:
# religion               7997
# age                    7990
# ethnicity              7959
# gender                 7945
# not_cyberbullying      7935
# other_cyberbullying    7821
# Name: bully_type, dtype: int64

# %% [markdown]
# The classes seem balanced

# %% [markdown]
# ## Apply Deep Cleaning - Tweet Text
# ### In this deep cleaning, we going to apply:
# * Strip emoji
# * Strip all entities
# * Decontract
#
# *This Deep Cleaning is more comprehensive than previous one, because previous was meant for data exploration, while the complex one are necessary for our LSTM model to learn more efficient and effectively.

# %%
#Import all the library for deep cleansing
import re, string
import emoji #!pip install emoji
import nltk #!pip install nltk
from nltk.stem import WordNetLemmatizer,PorterStemmer
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('punkt')
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
##CUSTOM DEFINED FUNCTIONS TO CLEAN THE TWEETS

# Remove all emojis from text, since it is a twitter it might include some amount of emojis
def strip_emoji(text):
    return re.sub(emoji.get_emoji_regexp(), r"", text) #remove emoji

#Remove punctuations, links, stopwords, mentions and \r\n new line characters
def strip_all_entities(text): 
    text = text.replace('\r', '').replace('\n', ' ').lower() #remove \n and \r and lowercase
    text = re.sub(r"(?:\@|https?\://)\S+", "", text) #remove links and mentions
    text = re.sub(r'[^\x00-\x7f]',r'', text) #remove non utf8/ascii characters such as '\x9a\x91\x97\x9a\x97'
    banned_list= string.punctuation
    table = str.maketrans('', '', banned_list)
    text = text.translate(table)
    text = [word for word in text.split() if word not in stop_words]
    text = ' '.join(text)
    text =' '.join(word for word in text.split() if len(word) < 14) # remove words longer than 14 characters
    return text

#remove contractions
def decontract(text):
    text = re.sub(r"can\'t", "can not", text)
    text = re.sub(r"n\'t", " not", text)
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"\'s", " is", text)
    text = re.sub(r"\'d", " would", text)
    text = re.sub(r"\'ll", " will", text)
    text = re.sub(r"\'t", " not", text)
    text = re.sub(r"\'ve", " have", text)
    text = re.sub(r"\'m", " am", text)
    return text

#clean hashtags at the end of the sentence, and keep those in the middle of the sentence by removing just the "#" symbol
def clean_hashtags(tweet):
    new_tweet = " ".join(word.strip() for word in re.split('#(?!(?:hashtag)\b)[\w-]+(?=(?:\s+#[\w-]+)*\s*$)', tweet)) #remove last hashtags
    new_tweet2 = " ".join(word.strip() for word in re.split('#|_', new_tweet)) #remove hashtags symbol from words in the middle of the sentence
    return new_tweet2

#Filter special characters such as "&" and "$" present in some words
def filter_chars(a):
    sent = []
    for word in a.split(' '):
        if ('$' in word) | ('&' in word):
            sent.append('')
        else:
            sent.append(word)
    return ' '.join(sent)

#Remove multiple sequential spaces
def remove_mult_spaces(text):
    return re.sub("\s\s+" , " ", text)

#Stemming
def stemmer(text):
    tokenized = nltk.word_tokenize(text)
    ps = PorterStemmer()
    return ' '.join([ps.stem(words) for words in tokenized])

#Lemmatization 
#NOTE:Stemming seems to work better for this dataset
def lemmatize(text):
    tokenized = nltk.word_tokenize(text)
    lm = WordNetLemmatizer()
    return ' '.join([lm.lemmatize(words) for words in tokenized])

#Then we apply all the defined functions in the following order
def deep_clean(text):
    text = strip_emoji(text)
    text = decontract(text)
    text = strip_all_entities(text)
    text = clean_hashtags(text)
    text = filter_chars(text)
    text = remove_mult_spaces(text)
    text = stemmer(text)
    return text

# %%
new_texts = []
for each_text in df['text']:
    new_texts.append(deep_clean(each_text))
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1424\3236355396.py:5: DeprecationWarning:
#
# 'emoji.get_emoji_regexp()' is deprecated and will be removed in version 2.0.0. If you want to remove emoji from a string, consider the method emoji.replace_emoji(str, replace='').
# To hide this warning, pin/downgrade the package to 'emoji~=1.6.3'

# %% [markdown]
# Now we will add `df` Data Frame with a new columns called `new_text`, using deep cleaned text

# %%
df['clean_text'] = new_texts

# %%
df.head()
# Out:
#                                                                                                                                            text  \
# 0                                                                                 In other words #katandandre, your food was crapilicious! #mkr
# 1                                                                  @gcarothers eek. i can't stand split keyboards. doesn't work well with MMOs.
# 2            @GlennF @Spacekatgal it is rather funny how all of us are so completely different, yet complement each other's skill sets so well.
# 3  @jukes303 The old oil cliche again. The US pays for every drop of oil they get from the ME on the open market just like every other country.
# 4                           Why is #aussietv so white? #MKR #theblock #ImACelebrityAU #today #sunrise #studio10 #Neighbours #WonderlandTen #etc
#
#           bully_type  \
# 0  not_cyberbullying
# 1  not_cyberbullying
# 2  not_cyberbullying
# 3  not_cyberbullying
# 4  not_cyberbullying
#
#                                                                       clean_text
# 0                                             word katandandr food crapilici mkr
# 1                                         eek stand split keyboard work well mmo
# 2                   rather funni us complet differ yet complement skill set well
# 3         old oil clich us pay everi drop oil get open market like everi countri
# 4  aussietv white mkr theblock today sunris studio10 neighbour wonderlandten etc

# %%
df.tail()
# Out:
#                                                                                                                                                                                                                                                                                        text  \
# 47688                                            Black ppl aren't expected to do anything, depended on for anything. Yet free to participate, work, enjoy the freedom of humans all across this globe. If you waste your energy on the past you will be wasting it for building the future.
# 47689  Turner did not withhold his disappointment. Turner called the court an “abominable conclave of negro hating demons” (with one exception) who “issued another decree that colored men and women must be driven into Jim Crow cars whenever it suits the whim of any white community.”
# 47690                                                                                                                                                                              I swear to God. This dumb nigger bitch. I have got to bleach my hair reeeeeal fuckin' soon. D:&lt; FUCK.
# 47691                                                                                                                                                                                            Yea fuck you RT @therealexel: IF YOURE A NIGGER FUCKING UNFOLLOW ME, FUCKING DUMB NIGGERS.
# 47692                                                                                                                                                                                                          Bro. U gotta chill RT @CHILLShrammy: Dog FUCK KP that dumb nigger bitch lmao
#
#       bully_type  \
# 47688  ethnicity
# 47689  ethnicity
# 47690  ethnicity
# 47691  ethnicity
# 47692  ethnicity
#
#                                                                                                                                                                  clean_text
# 47688                                         black ppl expect anyth depend anyth yet free particip work enjoy freedom human across globe wast energi past wast build futur
# 47689  turner withhold turner call court abomin conclav negro hate demon one except issu anoth decre color men women must driven jim crow car whenev suit whim white commun
# 47690                                                                                             swear god dumb nigger bitch got bleach hair reeeeeal fuckin soon dlt fuck
# 47691                                                                                                                yea fuck rt your nigger fuck unfollow fuck dumb nigger
# 47692                                                                                                              bro u got ta chill rt dog fuck kp dumb nigger bitch lmao

# %%
# Ultilize string interpolate to print information more clearly with label
print(f'Shape: {df.shape}')
sum_duplicate = df["clean_text"].duplicated().sum()
print(f'Duplicated Sum: {sum_duplicate}')
# Out:
# Shape: (47647, 3)
# Duplicated Sum: 3061

# %%
df.drop_duplicates("clean_text", inplace=True) # Apply Inplace = True to actually apply into the df

# %%
df.shape
# Out:
# (44586, 3)

# %%
# Recheck Class Balance
df['bully_type'].value_counts()
# Out:
# religion               7945
# age                    7881
# ethnicity              7743
# not_cyberbullying      7635
# gender                 7604
# other_cyberbullying    5778
# Name: bully_type, dtype: int64

# %% [markdown]
# As we can see, most of the dropped duplicated instance are from `other_cyberbullying` class, which make the class drop to `5,778` compare to other `7,xxx`

# %%
df = df[df["bully_type"]!="other_cyberbullying"]
#classes = ["religion","age","ethnicity","gender","not bullying"]

# %% [markdown]
# ### Tweet Text Length Analysis
# Now we will create a new column called `text_length` in `df`, calculating the word length and input in it, so it is more easy to view and do plotting

# %%
text_length = []
for each_text in df['clean_text']:
    each_length = len(each_text.split())
    text_length.append(each_length)

# %%
# Apply the text length list array into data frame
df['text_length'] = text_length
df.head()
# Out:
#                                                                                                                                            text  \
# 0                                                                                 In other words #katandandre, your food was crapilicious! #mkr
# 1                                                                  @gcarothers eek. i can't stand split keyboards. doesn't work well with MMOs.
# 2            @GlennF @Spacekatgal it is rather funny how all of us are so completely different, yet complement each other's skill sets so well.
# 3  @jukes303 The old oil cliche again. The US pays for every drop of oil they get from the ME on the open market just like every other country.
# 4                           Why is #aussietv so white? #MKR #theblock #ImACelebrityAU #today #sunrise #studio10 #Neighbours #WonderlandTen #etc
#
#           bully_type  \
# 0  not_cyberbullying
# 1  not_cyberbullying
# 2  not_cyberbullying
# 3  not_cyberbullying
# 4  not_cyberbullying
#
#                                                                       clean_text  \
# 0                                             word katandandr food crapilici mkr
# 1                                         eek stand split keyboard work well mmo
# 2                   rather funni us complet differ yet complement skill set well
# 3         old oil clich us pay everi drop oil get open market like everi countri
# 4  aussietv white mkr theblock today sunris studio10 neighbour wonderlandten etc
#
#    text_length
# 0            5
# 1            7
# 2           10
# 3           14
# 4           10

# %%
plt.figure(figsize=(8,5))
ax = sns.countplot(x='text_length', data=df[df['text_length']<10], palette='mako')
plt.title('Count of cleaned tweets with less than 10 words', fontsize=20)
plt.yticks([])
ax.bar_label(ax.containers[0])
plt.ylabel('count')
plt.xlabel('')
plt.show()

# %% [markdown]
# If a tweets are too shorted, Deep Learning Model will not able to make sense of it, it will become the problematic outlier that will ruin the accuracy of the model while training and validationg.
#
# We will remove tweets that are too short (less or equal than `3 words`).

# %%
df = df[df['text_length'] > 3]

# %% [markdown]
# We also need to check about tweet text that are too long, if a tweet had more than `100++` words that it is considered outlier that can affect the model too.

# %%
pd.set_option('display.max_colwidth', 100)
df.sort_values(by=['text_length'], ascending=False)
# Out:
#                                                                                                       text  \
# 44036  You so black and white trying to live like a nigger... Pahahahaha... Common is dumb as fuck!\r\n...
# 45166  @hermdiggz: “@tayyoung_: FUCK OBAMA, dumb ass nigger” this bitch &lt;~~This Whore SMH\r\nI don’t...
# 1318   @EurekAlertAAAS: Researchers push to import top anti-bullying program to US schools http://t.co/...
# 33725  ... I don't feel guilty for killing him, I just feel guilty because I enjoyed it. He tormented s...
# 47038  @Purely_Ambition: Sooo mad. RT @TracePeterson Fuck Obama that dumb nigger I'm going to Switzerla...
# ...                                                                                                    ...
# 33591                                                                           HIGH SCHOOL FCKIN BULLIES.
# 5834                            Just because we're not close anymore doesn't mean I don't care about you..
# 5839                                                                          Isso é bullying com a cocota
# 12440            RT @Rhys_Dempsey29 Where the women should be #notsexist #justfunny http://t.co/PdfuIvUyG8
# 2221                                        @mcmahoniel unfortunately, no. text filters are too high-risk.
#
#               bully_type  \
# 44036          ethnicity
# 45166          ethnicity
# 1318   not_cyberbullying
# 33725                age
# 47038          ethnicity
# ...                  ...
# 33591                age
# 5834   not_cyberbullying
# 5839   not_cyberbullying
# 12440             gender
# 2221   not_cyberbullying
#
#                                                                                                 clean_text  \
# 44036  black white tri live like nigger pahahahaha common dumb fuck short huntsman dumb ass ya fuck gay...
# 45166  fuck obama dumb ass nigger bitch ltthi whore smh dont think either dont put anyth past nigga com...
# 1318   research push import top antibulli program us school instead person attack mayb explain 100 isla...
# 33725  feel guilti kill feel guilti enjoy torment sinc child even let bulli school harass almost cut ey...
# 47038  sooo mad rt fuck obama dumb nigger go switzerlan yooomaddddddd lmfaoo shut fuck dumb nigger sout...
# ...                                                                                                    ...
# 33591                                                                              high school fckin bulli
# 5834                                                                                close anymor mean care
# 5839                                                                                 isso bulli com cocota
# 12440                                                                         rt women notsexist justfunni
# 2221                                                                         unfortun text filter highrisk
#
#        text_length
# 44036          187
# 45166          162
# 1318           137
# 33725          137
# 47038          125
# ...            ...
# 33591            4
# 5834             4
# 5839             4
# 12440            4
# 2221             4
#
# [37111 rows x 4 columns]

# %%
# Now we want to use countplot to plot the length size of the tweet text, length in between 10 to 1000

plt.figure(figsize=(16,5))
ax = sns.countplot(x='text_length', data=df[(df['text_length']<=1000) & (df['text_length']>10)], palette='Blues_r')
plt.title('Count of tweets with high number of words', fontsize=25)
plt.yticks([])
ax.bar_label(ax.containers[0])
plt.ylabel('count')
plt.xlabel('')
plt.show()

# %% [markdown]
# As we can see from the graph, most tweets text length are from 11 to 30 which are good, decided to drop text length logner than 100.

# %%
df = df[df['text_length'] < 100]

# %%
max_length = np.max(df['text_length'])
max_length
# Out:
# 79

# %%
df.sort_values(by=["text_length"], ascending=False)
# Out:
#                                                                                                       text  \
# 4847   @andrea_gcav: @viviaanajim recuerdas como nosotras también eramos victimas del bullying/ jajaja ...
# 44295  @JasmineLovvee If He Dont Want You Well Fuck Him , He Aint Worth Your Tears , Never Sweat A Dumb...
# 45931  Get off ur ego trip, take off ur rose colored glasses &amp; get real! U’ll be lucky if ur in off...
# 41750  @seijohgorl hoy mami keito AAAA okay so um ikaw talaga one of my first closest moots omg startin...
# 21242  And yet God was able to meet their needs using radical, everyday generosity.” You may be familia...
# ...                                                                                                    ...
# 6312                                   @SteveStreza but you might ask @cperciva - i'm pretty sure he does.
# 6309                             RT @ashleylynch: No remark necessary for this one. http://t.co/iswNgFsgOw
# 6264   @tarah @girlziplocked @hypatiadotca @justkelly_ok @ameliagreenhall well, you have his support, b...
# 6255                                        @nicollezinha1 @Anniiinhah_ a nicol sofreu bullying kkkkkkkkkk
# 7365   @Vandaliser @sajid_fairooz @IsraeliRegime Here is an example. The process of sentencing under Sh...
#
#               bully_type  \
# 4847   not_cyberbullying
# 44295          ethnicity
# 45931          ethnicity
# 41750          ethnicity
# 21242           religion
# ...                  ...
# 6312   not_cyberbullying
# 6309   not_cyberbullying
# 6264   not_cyberbullying
# 6255   not_cyberbullying
# 7365   not_cyberbullying
#
#                                                                                                 clean_text  \
# 4847   recuerda como nosotra tambin eramo victima del bulli jajaja callat marc cuando nosotra bulleabam...
# 44295  dont want well fuck aint worth tear never sweat dumb nigger sound like 85 mad dumb go fuck black...
# 45931  get ur ego trip take ur rose color glass amp get real ull lucki ur offic next year ppl r fed ur ...
# 41750  hoy mami keito aaaa okay um ikaw talaga one first closest moot omg start bottom aaaa sobrang app...
# 21242  yet god abl meet need use radic everyday generos may familiar call stori differ week share stori...
# ...                                                                                                    ...
# 6312                                                                                 might ask pretti sure
# 6309                                                                               rt remark necessari one
# 6264                                                                                well support lost mine
# 6255                                                                         nicol sofreu bulli kkkkkkkkkk
# 7365                                                                         exampl process sentenc sharia
#
#        text_length
# 4847            79
# 44295           73
# 45931           45
# 41750           43
# 21242           43
# ...            ...
# 6312             4
# 6309             4
# 6264             4
# 6255             4
# 7365             4
#
# [37102 rows x 4 columns]

# %% [markdown]
# # Cyberbullying Type Encoding

# %%
cyberbully_type_dictionary = {
    'religion': 0,
    'age': 1,
    'ethnicity': 2,
    'gender': 3,
    #'other_cyberbullying': 4, Since class too less dropped
    'not_cyberbullying': 4
}

# %%
df['bully_type'] = df['bully_type'].replace(cyberbully_type_dictionary)
df.head()
# Out:
#                                                                                                   text  \
# 0                                        In other words #katandandre, your food was crapilicious! #mkr
# 1                         @gcarothers eek. i can't stand split keyboards. doesn't work well with MMOs.
# 2  @GlennF @Spacekatgal it is rather funny how all of us are so completely different, yet complemen...
# 3  @jukes303 The old oil cliche again. The US pays for every drop of oil they get from the ME on th...
# 4  Why is #aussietv so white? #MKR #theblock #ImACelebrityAU #today #sunrise #studio10 #Neighbours ...
#
#    bully_type  \
# 0           4
# 1           4
# 2           4
# 3           4
# 4           4
#
#                                                                       clean_text  \
# 0                                             word katandandr food crapilici mkr
# 1                                         eek stand split keyboard work well mmo
# 2                   rather funni us complet differ yet complement skill set well
# 3         old oil clich us pay everi drop oil get open market like everi countri
# 4  aussietv white mkr theblock today sunris studio10 neighbour wonderlandten etc
#
#    text_length
# 0            5
# 1            7
# 2           10
# 3           14
# 4           10

# %% [markdown]
# # Data preprocessing for LSTM

# %% [markdown]
# We going to take df `clean_text` columns  X datasets and `bully_type` for y datasets only, noted that the X is capital as purpose for naming convetion while y is small letter

# %%
X = df['clean_text']
y = df['bully_type']

# %%
from sklearn.model_selection import train_test_split

seed_value = 42
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=seed_value)

# %%
print(f'X_train: {X_train.shape}')
print(f'y_train: {y_train.shape}')
print(f'X_test: {X_test.shape}')
print(f'y_test: {y_test.shape}')
# Out:
# X_train: (29681,)
# y_train: (29681,)
# X_test: (7421,)
# y_test: (7421,)

# %%
max_features = 10000
maxlen = 300

# %%
from keras.preprocessing import text,sequence

tokenizer = text.Tokenizer(num_words=max_features)
tokenizer.fit_on_texts(X_train)
tokenized_train = tokenizer.texts_to_sequences(X_train)
X_train = sequence.pad_sequences(tokenized_train, maxlen=maxlen)

# %%
tokenized_test = tokenizer.texts_to_sequences(X_test)
X_test = sequence.pad_sequences(tokenized_test, maxlen=maxlen)

# %%
X_test
# Out:
# array([[   0,    0,    0, ...,  221, 1107,  227],
#        [   0,    0,    0, ...,  120, 1114,  229],
#        [   0,    0,    0, ...,  858,  120,   84],
#        ...,
#        [   0,    0,    0, ...,   61,  177,  397],
#        [   0,    0,    0, ...,   28, 1114, 1356],
#        [   0,    0,    0, ...,   40,   36,  253]])

# %%
X_train
# Out:
# array([[   0,    0,    0, ...,    4, 1356, 2629],
#        [   0,    0,    0, ...,  116,   47, 4113],
#        [   0,    0,    0, ...,  249,  394,   34],
#        ...,
#        [   0,    0,    0, ...,    8,   23,   26],
#        [   0,    0,    0, ...,    1,  206, 1820],
#        [   0,    0,    0, ..., 2697, 6578, 5343]])

# %%
y_test
# Out:
# 22195    0
# 5456     4
# 42325    2
# 45279    2
# 33454    1
#         ..
# 5584     4
# 10904    3
# 43580    2
# 7542     4
# 35113    1
# Name: bully_type, Length: 7421, dtype: int64

# %% [markdown]
# # Model Building

# %% [markdown]
# ## First LSTM Model

# %%
from keras.models import Sequential
from keras.layers import Dense, Bidirectional, LSTM, Embedding

# %%
batch_size = 256
epochs = 50
embed_size = 100

# %%
model = Sequential()

#Non-trainable embeddidng layer
model.add(Embedding(max_features, output_dim=embed_size, input_length=maxlen, trainable=False))

#LSTM 
model.add(LSTM(units=256 , return_sequences = True, dropout = 0.25, activation='tanh', recurrent_activation='sigmoid'))
model.add(LSTM(units=128, dropout = 0.1, activation='tanh', recurrent_activation='sigmoid'))

# Hidden Layer
model.add(Dense(units=128 , activation = 'relu'))
model.add(Dense(units=64 , activation = 'relu'))
model.add(Dense(units=32 , activation = 'relu'))
model.add(Dense(5, activation='softmax'))
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 300, 100)          1000000
#
#  lstm (LSTM)                 (None, 300, 256)          365568
#
#  lstm_1 (LSTM)               (None, 128)               197120
#
#  dense (Dense)               (None, 128)               16512
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dense_3 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 1,589,701
# Trainable params: 589,701
# Non-trainable params: 1,000,000
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, validation_split=0.1, epochs=50, batch_size=batch_size)
# Out:
# Epoch 1/50
# 105/105 [==============================] - 13s 91ms/step - loss: 1.2957 - accuracy: 0.4417 - val_loss: 0.7916 - val_accuracy: 0.7019
# Epoch 2/50
# 105/105 [==============================] - 9s 87ms/step - loss: 0.6991 - accuracy: 0.7270 - val_loss: 0.5768 - val_accuracy: 0.7797
# Epoch 3/50
# 105/105 [==============================] - 9s 87ms/step - loss: 0.5855 - accuracy: 0.7712 - val_loss: 0.5081 - val_accuracy: 0.8097
# Epoch 4/50
# 105/105 [==============================] - 9s 87ms/step - loss: 0.5141 - accuracy: 0.8022 - val_loss: 0.4791 - val_accuracy: 0.8114
# Epoch 5/50
# 105/105 [==============================] - 9s 87ms/step - loss: 0.4824 - accuracy: 0.8126 - val_loss: 0.4620 - val_accuracy: 0.8225
# Epoch 6/50
# 105/105 [==============================] - 9s 87ms/step - loss: 0.4483 - accuracy: 0.8291 - val_loss: 0.4255 - val_accuracy: 0.8414
# Epoch 7/50
# 105/105 [==============================] - 9s 87ms/step - loss: 0.4211 - accuracy: 0.8402 - val_loss: 0.3890 - val_accuracy: 0.8528
# Epoch 8/50
# 105/105 [==============================] - 9s 87ms/step - loss: 0.3970 - accuracy: 0.8506 - val_loss: 0.3866 - val_accuracy: 0.8558
# Epoch 9/50
# 105/105 [==============================] - 9s 89ms/step - loss: 0.3815 - accuracy: 0.8546 - val_loss: 0.3624 - val_accuracy: 0.8636
# Epoch 10/50
# 105/105 [==============================] - 9s 90ms/step - loss: 0.3651 - accuracy: 0.8613 - val_loss: 0.3455 - val_accuracy: 0.8730
# Epoch 11/50
# 105/105 [==============================] - 9s 88ms/step - loss: 0.3514 - accuracy: 0.8661 - val_loss: 0.3348 - val_accuracy: 0.8761
# Epoch 12/50
# 105/105 [==============================] - 9s 87ms/step - loss: 0.3334 - accuracy: 0.8749 - val_loss: 0.3244 - val_accuracy: 0.8774
# Epoch 13/50
# 105/105 [==============================] - 9s 87ms/step - loss: 0.3142 - accuracy: 0.8822 - val_loss: 0.3218 - val_accuracy: 0.8808
# Epoch 14/50
# 105/105 [==============================] - 9s 87ms/step - loss: 0.3038 - accuracy: 0.8855 - val_loss: 0.3116 - val_accuracy: 0.8811
# Epoch 15/50
# 105/105 [==============================] - 9s 87ms/step - loss: 0.2895 - accuracy: 0.8912 - val_loss: 0.2981 - val_accuracy: 0.8838
# Epoch 16/50
# 105/105 [==============================] - 9s 87ms/step - loss: 0.2831 - accuracy: 0.8938 - val_loss: 0.2901 - val_accuracy: 0.8858
# Epoch 17/50
# 105/105 [==============================] - 9s 87ms/step - loss: 0.2777 - accuracy: 0.8952 - val_loss: 0.2863 - val_accuracy: 0.8915
# Epoch 18/50
# 105/105 [==============================] - 9s 87ms/step - loss: 0.2743 - accuracy: 0.8954 - val_loss: 0.2711 - val_accuracy: 0.8953
# Epoch 19/50
# 105/105 [==============================] - 9s 87ms/step - loss: 0.
50
# 105/105 [==============================] - 9s 87ms/step - loss: 0.1581 - accuracy: 0.9391 - val_loss: 0.2573 - val_accuracy: 0.9175
# Epoch 50/50
# 105/105 [==============================] - 9s 87ms/step - loss: 0.1546 - accuracy: 0.9395 - val_loss: 0.2589 - val_accuracy: 0.9171

# %%
print("Accuracy of the model on Training Data is - " , model.evaluate(X_train,y_train)[1]*100 , "%")
print("Accuracy of the model on Testing Data is - " , model.evaluate(X_test,y_test)[1]*100 , "%")
# Out:
# 928/928 [==============================] - 15s 16ms/step - loss: 0.1379 - accuracy: 0.9464
# Accuracy of the model on Training Data is -  94.64303851127625 %
# 232/232 [==============================] - 4s 16ms/step - loss: 0.2304 - accuracy: 0.9236
# Accuracy of the model on Testing Data is -  92.35951900482178 %

# %%
# Evaluation matrix
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc)+1)

plt.plot(epochs, acc, 'b', label='Train Accuracy')
plt.plot(epochs, val_acc, 'r', label='Val Accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'b', label='Train Loss')
plt.plot(epochs, val_loss, 'r', label='Val Loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
from sklearn.metrics import multilabel_confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

predict_x = model.predict(X_test)
y_pred = np.argmax(predict_x,axis=1)

cf = confusion_matrix(y_test, y_pred)
cf
# Out:
# array([[1481,    1,    4,    4,   89],
#        [   2, 1528,    2,    1,   33],
#        [   7,    3, 1495,    7,   29],
#        [  16,    2,    5, 1207,  231],
#        [  65,   23,    3,   40, 1143]], dtype=int64)

# %%
import seaborn as sns
x_axis_labels = ['religion', 'age', 'ethnicity', 'gender', 'not bullying']
y_axis_labels = ['religion', 'age', 'ethnicity', 'gender', 'not bullying']
ax = sns.heatmap(cf, annot=True, cmap='Blues', fmt='g', xticklabels=x_axis_labels, yticklabels=y_axis_labels)

ax.set_title('Seaborn Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

## Display the visualization of the Confusion Matrix.
plt.show()

# %%
# Generate classification report with precision, recall and f1-score
from sklearn.metrics import classification_report

classes_list = ['religion', 'age', 'ethnicity', 'gender', 'not bullying']
print(classification_report(y_test, y_pred, target_names = classes_list))
# Out:
#               precision    recall  f1-score   support
#
#     religion       0.94      0.94      0.94      1579
#          age       0.98      0.98      0.98      1566
#    ethnicity       0.99      0.97      0.98      1541
#       gender       0.96      0.83      0.89      1461
# not bullying       0.75      0.90      0.82      1274
#
#     accuracy                           0.92      7421
#    macro avg       0.92      0.92      0.92      7421
# weighted avg       0.93      0.92      0.93      7421

# %% [markdown]
# ## Second LSTM Model

# %% [markdown]
# Higher dropout for LSTM which mean less memory store, with reduced LSTM units, More layer of dense with tanh activation function, finally one dropout

# %%
from keras.layers import Dropout
model2 = Sequential()

#Non-trainable embeddidng layer
model2.add(Embedding(max_features, output_dim=embed_size, input_length=maxlen, trainable=False))

#LSTM 
model2.add(LSTM(units=128 , return_sequences = True, dropout = 0.45, activation='tanh', recurrent_activation='sigmoid'))
model2.add(LSTM(units=64, dropout = 0.35, activation='tanh', recurrent_activation='sigmoid'))

# Hidden Layer
model2.add(Dense(units=256 , activation = 'tanh'))
model2.add(Dense(units=128 , activation = 'tanh'))
model2.add(Dense(units=64 , activation = 'tanh'))
model2.add(Dense(units=32 , activation = 'tanh'))
model2.add(Dropout(0.2))
model2.add(Dense(5, activation='softmax'))
model2.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 300, 100)          1000000
#
#  lstm_2 (LSTM)               (None, 300, 128)          117248
#
#  lstm_3 (LSTM)               (None, 64)                49408
#
#  dense_4 (Dense)             (None, 256)               16640
#
#  dense_5 (Dense)             (None, 128)               32896
#
#  dense_6 (Dense)             (None, 64)                8256
#
#  dense_7 (Dense)             (None, 32)                2080
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_8 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 1,226,693
# Trainable params: 226,693
# Non-trainable params: 1,000,000
# _________________________________________________________________

# %%
epochs2 = 60
history2 = model2.fit(X_train, y_train, validation_split=0.1, epochs=epochs2, batch_size=128)
# Out:
# Epoch 1/60
# 209/209 [==============================] - 11s 46ms/step - loss: 0.9341 - accuracy: 0.6283 - val_loss: 0.6464 - val_accuracy: 0.7599
# Epoch 2/60
# 209/209 [==============================] - 9s 43ms/step - loss: 0.6661 - accuracy: 0.7503 - val_loss: 0.5274 - val_accuracy: 0.7939
# Epoch 3/60
# 209/209 [==============================] - 9s 43ms/step - loss: 0.6023 - accuracy: 0.7755 - val_loss: 0.5064 - val_accuracy: 0.8094
# Epoch 4/60
# 209/209 [==============================] - 9s 43ms/step - loss: 0.5590 - accuracy: 0.7902 - val_loss: 0.4758 - val_accuracy: 0.8245
# Epoch 5/60
# 209/209 [==============================] - 9s 44ms/step - loss: 0.5223 - accuracy: 0.8026 - val_loss: 0.4449 - val_accuracy: 0.8282
# Epoch 6/60
# 209/209 [==============================] - 10s 47ms/step - loss: 0.4851 - accuracy: 0.8189 - val_loss: 0.4232 - val_accuracy: 0.8410
# Epoch 7/60
# 209/209 [==============================] - 9s 45ms/step - loss: 0.4591 - accuracy: 0.8270 - val_loss: 0.3809 - val_accuracy: 0.8649
# Epoch 8/60
# 209/209 [==============================] - 9s 43ms/step - loss: 0.4185 - accuracy: 0.8434 - val_loss: 0.3532 - val_accuracy: 0.8680
# Epoch 9/60
# 209/209 [==============================] - 9s 44ms/step - loss: 0.3989 - accuracy: 0.8521 - val_loss: 0.3461 - val_accuracy: 0.8720
# Epoch 10/60
# 209/209 [==============================] - 9s 43ms/step - loss: 0.3820 - accuracy: 0.8598 - val_loss: 0.3199 - val_accuracy: 0.8814
# Epoch 11/60
# 209/209 [==============================] - 9s 44ms/step - loss: 0.3644 - accuracy: 0.8670 - val_loss: 0.3191 - val_accuracy: 0.8744
# Epoch 12/60
# 209/209 [==============================] - 9s 43ms/step - loss: 0.3476 - accuracy: 0.8703 - val_loss: 0.3070 - val_accuracy: 0.8868
# Epoch 13/60
# 209/209 [==============================] - 9s 43ms/step - loss: 0.3374 - accuracy: 0.8754 - val_loss: 0.3243 - val_accuracy: 0.8764
# Epoch 14/60
# 209/209 [==============================] - 9s 43ms/step - loss: 0.3284 - accuracy: 0.8796 - val_loss: 0.2841 - val_accuracy: 0.8929
# Epoch 15/60
# 209/209 [==============================] - 9s 44ms/step - loss: 0.3206 - accuracy: 0.8823 - val_loss: 0.3085 - val_accuracy: 0.8821
# Epoch 16/60
# 209/209 [==============================] - 9s 43ms/step - loss: 0.3166 - accuracy: 0.8841 - val_loss: 0.2861 - val_accuracy: 0.8946
# Epoch 17/60
# 209/209 [==============================] - 9s 44ms/step - loss: 0.3047 - accuracy: 0.8878 - val_loss: 0.2743 - val_accuracy: 0.9000
# Epoch 18/60
# 209/209 [==============================] - 9s 43ms/step - loss: 0.2979 - accuracy: 0.8908 - val_loss: 0.2754 - val_accuracy: 0.9050
# Epoch 19/60
# 209/209 [==============================] - 9s 44ms/step - loss: 0.2927 - accuracy: 0.8949 - val_loss: 0.2842 - val_accuracy: 0.8966
# Epoch 20/60
# 209/209 [==============================] - 9s 43ms/step - loss: 0.2865 - accuracy: 0.8955 - val_loss: 0.2652 - val_accuracy: 0.9060
# Epoch 21/60
# 209/209 [==============================] - 9s 42ms/step - loss: 0.2876 - accuracy: 0.8947 - val_loss: 0.2671 - val_accuracy: 0.9054
# Epoch 22/60
# 209/209 [==============================] - 9s 44ms/step - loss: 0.2848 - accuracy: 0.8957 - val_loss: 0.2588 - val_accuracy: 0.9104
# Epoch 23/60
# 209/209 [==============================] - 9s 44ms/step - loss: 0.2758 - accuracy: 0.9008 - val_loss: 0.2606 - val_accuracy: 0.9097
# Epoch 24/60
# 209/209 [==============================] - 9s 43ms/step - loss: 0.2711 - accuracy: 0.9031 - val_loss: 0.2588 - val_accuracy: 0.9074
# Epoch 25/60
# 209/209 [==============================] - 9s 43ms/step - loss: 0.2694 - accuracy: 0.9024 - val_loss: 0.2724 - val_accuracy: 0.9070
# Epoch 26/60
# 209/209 [==============================] - 9s 43ms/step - loss: 0.2643 - accuracy: 0.9063 - val_loss: 0.2660 - val_accuracy: 0.9097
# Epoch 27/60
# 209/209 [==============================] - 9s 43ms/step - loss: 0.2634 - accuracy: 0.9066 - val_loss: 0.2605 - val_accuracy: 0.9050
# Epoch 28/60
# 209/209 [==============================] - 9s 42ms/step - loss: 0.
60
# 209/209 [==============================] - 9s 43ms/step - loss: 0.2018 - accuracy: 0.9274 - val_loss: 0.2291 - val_accuracy: 0.9205
# Epoch 60/60
# 209/209 [==============================] - 9s 43ms/step - loss: 0.1947 - accuracy: 0.9275 - val_loss: 0.2242 - val_accuracy: 0.9249

# %%
print("Accuracy of the model on Training Data is - " , model2.evaluate(X_train,y_train)[1]*100 , "%")
print("Accuracy of the model on Testing Data is - " , model2.evaluate(X_test,y_test)[1]*100 , "%")
# Out:
# 928/928 [==============================] - 10s 11ms/step - loss: 0.1601 - accuracy: 0.9409
# Accuracy of the model on Training Data is -  94.0938651561737 %
# 232/232 [==============================] - 3s 11ms/step - loss: 0.2042 - accuracy: 0.9287
# Accuracy of the model on Testing Data is -  92.87158250808716 %

# %%
# Evaluation matrix
import matplotlib.pyplot as plt

acc2 = history2.history['accuracy']
val_acc2 = history2.history['val_accuracy']
loss2 = history2.history['loss']
val_loss2 = history2.history['val_loss']

epochs = range(1, len(acc2)+1)

plt.plot(epochs, acc2, 'b', label='Train Accuracy')
plt.plot(epochs, val_acc2, 'r', label='Val Accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss2, 'b', label='Train Loss')
plt.plot(epochs, val_loss2, 'r', label='Val Loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
from sklearn.metrics import multilabel_confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

predict_x2 = model2.predict(X_test)
y_pred2 = np.argmax(predict_x2,axis=1)

cf2 = confusion_matrix(y_test, y_pred2)
cf2
# Out:
# array([[1465,    1,    3,    4,  106],
#        [   2, 1530,    0,    0,   34],
#        [   2,    1, 1508,    4,   26],
#        [   4,    1,    5, 1229,  222],
#        [  49,   14,    7,   44, 1160]], dtype=int64)

# %%
import seaborn as sns
x_axis_labels = ['religion', 'age', 'ethnicity', 'gender', 'not bullying']
y_axis_labels = ['religion', 'age', 'ethnicity', 'gender', 'not bullying']
ax = sns.heatmap(cf2, annot=True, cmap='Blues', fmt='g', xticklabels=x_axis_labels, yticklabels=y_axis_labels)

ax.set_title('Seaborn Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

## Display the visualization of the Confusion Matrix.
plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred2, target_names = ['religion', 'age', 'ethnicity', 'gender', 'not bullying']))
# Out:
#               precision    recall  f1-score   support
#
#     religion       0.96      0.93      0.94      1579
#          age       0.99      0.98      0.98      1566
#    ethnicity       0.99      0.98      0.98      1541
#       gender       0.96      0.84      0.90      1461
# not bullying       0.75      0.91      0.82      1274
#
#     accuracy                           0.93      7421
#    macro avg       0.93      0.93      0.93      7421
# weighted avg       0.94      0.93      0.93      7421

# %% [markdown]
# # Third LSTM Model

# %%
from keras.layers import Dropout
model3 = Sequential()

#Non-trainable embeddidng layer
model3.add(Embedding(max_features, output_dim=embed_size, input_length=maxlen, trainable=False))

#LSTM 
model3.add(LSTM(units=512 , return_sequences = True, dropout = 0.20, activation='tanh', recurrent_activation='sigmoid'))
model3.add(LSTM(units=256, dropout = 0.20, activation='tanh', recurrent_activation='sigmoid'))

# Hidden Layer
model3.add(Dense(units=512 , activation = 'tanh'))
model3.add(Dense(units=256 , activation = 'tanh'))
model3.add(Dense(units=128 , activation = 'tanh'))
model3.add(Dropout(0.2))
model3.add(Dense(units=64 , activation = 'tanh'))
model3.add(Dropout(0.2))
model3.add(Dense(units=32 , activation = 'tanh'))
model3.add(Dropout(0.2))
model3.add(Dense(5, activation='softmax'))
model3.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 300, 100)          1000000
#
#  lstm_4 (LSTM)               (None, 300, 512)          1255424
#
#  lstm_5 (LSTM)               (None, 256)               787456
#
#  dense_9 (Dense)             (None, 512)               131584
#
#  dense_10 (Dense)            (None, 256)               131328
#
#  dense_11 (Dense)            (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_12 (Dense)            (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_13 (Dense)            (None, 32)                2080
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_14 (Dense)            (None, 5)                 165
#
# =================================================================
# Total params: 3,349,189
# Trainable params: 2,349,189
# Non-trainable params: 1,000,000
# _________________________________________________________________

# %%
epochs3 = 60
history3 = model3.fit(X_train, y_train, validation_split=0.1, epochs=epochs3, batch_size=128)
# Out:
# Epoch 1/60
# 209/209 [==============================] - 28s 123ms/step - loss: 0.8769 - accuracy: 0.6554 - val_loss: 0.6491 - val_accuracy: 0.7588
# Epoch 2/60
# 209/209 [==============================] - 25s 122ms/step - loss: 0.6359 - accuracy: 0.7634 - val_loss: 0.5244 - val_accuracy: 0.8070
# Epoch 3/60
# 209/209 [==============================] - 25s 119ms/step - loss: 0.5339 - accuracy: 0.8033 - val_loss: 0.4664 - val_accuracy: 0.8255
# Epoch 4/60
# 209/209 [==============================] - 25s 119ms/step - loss: 0.4573 - accuracy: 0.8323 - val_loss: 0.4286 - val_accuracy: 0.8407
# Epoch 5/60
# 209/209 [==============================] - 25s 118ms/step - loss: 0.3921 - accuracy: 0.8628 - val_loss: 0.3769 - val_accuracy: 0.8636
# Epoch 6/60
# 209/209 [==============================] - 25s 119ms/step - loss: 0.3616 - accuracy: 0.8713 - val_loss: 0.3431 - val_accuracy: 0.8794
# Epoch 7/60
# 209/209 [==============================] - 25s 119ms/step - loss: 0.3426 - accuracy: 0.8811 - val_loss: 0.3486 - val_accuracy: 0.8787
# Epoch 8/60
# 209/209 [==============================] - 25s 119ms/step - loss: 0.3286 - accuracy: 0.8863 - val_loss: 0.3377 - val_accuracy: 0.8838
# Epoch 9/60
# 209/209 [==============================] - 25s 120ms/step - loss: 0.3117 - accuracy: 0.8909 - val_loss: 0.3100 - val_accuracy: 0.8895
# Epoch 10/60
# 209/209 [==============================] - 25s 120ms/step - loss: 0.3069 - accuracy: 0.8938 - val_loss: 0.3037 - val_accuracy: 0.8915
# Epoch 11/60
# 209/209 [==============================] - 25s 118ms/step - loss: 0.2930 - accuracy: 0.8978 - val_loss: 0.3151 - val_accuracy: 0.8915
# Epoch 12/60
# 209/209 [==============================] - 25s 119ms/step - loss: 0.2853 - accuracy: 0.8999 - val_loss: 0.2897 - val_accuracy: 0.8969
# Epoch 13/60
# 209/209 [==============================] - 25s 120ms/step - loss: 0.2748 - accuracy: 0.9032 - val_loss: 0.3118 - val_accuracy: 0.8912
# Epoch 14/60
# 209/209 [==============================] - 25s 119ms/step - loss: 0.2706 - accuracy: 0.9063 - val_loss: 0.2895 - val_accuracy: 0.8979
# Epoch 15/60
# 209/209 [==============================] - 25s 119ms/step - loss: 0.2623 - accuracy: 0.9108 - val_loss: 0.2727 - val_accuracy: 0.9033
# Epoch 16/60
# 209/209 [==============================] - 25s 119ms/step - loss: 0.2550 - accuracy: 0.9113 - val_loss: 0.2954 - val_accuracy: 0.8979
# Epoch 17/60
# 209/209 [==============================] - 25s 120ms/step - loss: 0.2431 - accuracy: 0.9165 - val_loss: 0.2772 - val_accuracy: 0.9087
# Epoch 18/60
# 209/209 [==============================] - 25s 120ms/step - loss: 0.2380 - accuracy: 0.9170 - val_loss: 0.2932 - val_accuracy: 0.9064
# Epoch 19/60
# 209/209 [==============================] - 25s 119ms/step - loss: 0.2376 - accuracy: 0.9184 - val_loss: 0.2604 - val_accuracy: 0.9094
# Epoch 20/60
# 209/209 [==============================] - 25s 120ms/step - loss: 0.2267 - accuracy: 0.9216 - val_loss: 0.2707 - val_accuracy: 0.9114
# Epoch 21/60
# 209/209 [==============================] - 25s 120ms/step - loss: 0.2239 - accuracy: 0.9222 - val_loss: 0.2598 - val_accuracy: 0.9141
# Epoch 22/60
# 209/209 [==============================] - 25s 120ms/step - loss: 0.2167 - accuracy: 0.9235 - val_loss: 0.2894 - val_accuracy: 0.9087
# Epoch 23/60
# 209/209 [==============================] - 25s 120ms/step - loss: 0.2093 - accuracy: 0.9278 - val_loss: 0.2679 - val_accuracy: 0.9128
# Epoch 24/60
# 209/209 [==============================] - 25s 119ms/step - loss: 0.
60
# 209/209 [==============================] - 25s 119ms/step - loss: 0.1007 - accuracy: 0.9653 - val_loss: 0.3572 - val_accuracy: 0.9094
# Epoch 50/60
# 209/209 [==============================] - 25s 118ms/step - loss: 0.1020 - accuracy: 0.9644 - val_loss: 0.3413 - val_accuracy: 0.9057
# Epoch 51/60
# 209/209 [==============================] - 25s 119ms/step - loss: 0.1010 - accuracy: 0.9643 - val_loss: 0.3254 - val_accuracy: 0.9141
# Epoch 52/60
# 209/209 [==============================] - 25s 118ms/step - loss: 0.0971 - accuracy: 0.9658 - val_loss: 0.3199 - val_accuracy: 0.9104
# Epoch 53/60
# 209/209 [==============================] - 25s 118ms/step - loss: 0.0917 - accuracy: 0.9684 - val_loss: 0.3264 - val_accuracy: 0.9144
# Epoch 54/60
# 209/209 [==============================] - 25s 118ms/step - loss: 0.0916 - accuracy: 0.9681 - val_loss: 0.3546 - val_accuracy: 0.9124
# Epoch 55/60
# 209/209 [==============================] - 25s 118ms/step - loss: 0.0827 - accuracy: 0.9712 - val_loss: 0.3519 - val_accuracy: 0.9171
# Epoch 56/60
# 209/209 [==============================] - 24s 117ms/step - loss: 0.0840 - accuracy: 0.9713 - val_loss: 0.3532 - val_accuracy: 0.9188
# Epoch 57/60
# 209/209 [==============================] - 24s 116ms/step - loss: 0.0741 - accuracy: 0.9744 - val_loss: 0.3474 - val_accuracy: 0.9188
# Epoch 58/60
# 209/209 [==============================] - 24s 116ms/step - loss: 0.0742 - accuracy: 0.9744 - val_loss: 0.3346 - val_accuracy: 0.9188
# Epoch 59/60
# 209/209 [==============================] - 24s 116ms/step - loss: 0.0741 - accuracy: 0.9739 - val_loss: 0.3655 - val_accuracy: 0.9128
# Epoch 60/60
# 209/209 [==============================] - 24s 116ms/step - loss: 0.0674 - accuracy: 0.9774 - val_loss: 0.3804 - val_accuracy: 0.9155

# %%
print("Accuracy of the model on Training Data is - " , model3.evaluate(X_train,y_train)[1]*100 , "%")
print("Accuracy of the model on Testing Data is - " , model3.evaluate(X_test,y_test)[1]*100 , "%")
# Out:
# 928/928 [==============================] - 29s 31ms/step - loss: 0.0695 - accuracy: 0.9802
# Accuracy of the model on Training Data is -  98.0189323425293 %
# 232/232 [==============================] - 7s 32ms/step - loss: 0.3753 - accuracy: 0.9167
# Accuracy of the model on Testing Data is -  91.672283411026 %

# %%
# Evaluation matrix
import matplotlib.pyplot as plt

acc3 = history3.history['accuracy']
val_acc3 = history3.history['val_accuracy']
loss3 = history3.history['loss']
val_loss3 = history3.history['val_loss']

epochs = range(1, len(acc3)+1)

plt.plot(epochs, acc3, 'b', label='Train Accuracy')
plt.plot(epochs, val_acc3, 'r', label='Val Accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss3, 'b', label='Train Loss')
plt.plot(epochs, val_loss3, 'r', label='Val Loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
from sklearn.metrics import multilabel_confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

predict_x3 = model3.predict(X_test)
y_pred3 = np.argmax(predict_x3,axis=1)

cf3 = confusion_matrix(y_test, y_pred3)
cf3
# Out:
# array([[1414,    0,    9,   18,  138],
#        [   2, 1521,    6,    1,   36],
#        [   4,    0, 1502,    9,   26],
#        [   2,    0,    3, 1233,  223],
#        [  40,   20,    5,   76, 1133]], dtype=int64)

# %%
import seaborn as sns
x_axis_labels = ['religion', 'age', 'ethnicity', 'gender', 'not bullying']
y_axis_labels = ['religion', 'age', 'ethnicity', 'gender', 'not bullying']
ax = sns.heatmap(cf3, annot=True, cmap='Blues', fmt='g', xticklabels=x_axis_labels, yticklabels=y_axis_labels)

ax.set_title('Seaborn Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

## Display the visualization of the Confusion Matrix.
plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred3, target_names = ['religion', 'age', 'ethnicity', 'gender', 'not bullying']))
# Out:
#               precision    recall  f1-score   support
#
#     religion       0.97      0.90      0.93      1579
#          age       0.99      0.97      0.98      1566
#    ethnicity       0.98      0.97      0.98      1541
#       gender       0.92      0.84      0.88      1461
# not bullying       0.73      0.89      0.80      1274
#
#     accuracy                           0.92      7421
#    macro avg       0.92      0.91      0.91      7421
# weighted avg       0.93      0.92      0.92      7421

# %% [markdown]
# ## Fourth LSTM model

# %% [markdown]
# Same as third but with Early Stopping 0.0001 adam learning rate and 200 epochs

# %%
from keras.layers import Dropout
model4 = Sequential()

#Non-trainable embeddidng layer
model4.add(Embedding(max_features, output_dim=embed_size, input_length=maxlen, trainable=False))

#LSTM 
model4.add(LSTM(units=512 , return_sequences = True, dropout = 0.20, activation='tanh', recurrent_activation='sigmoid'))
model4.add(LSTM(units=256, dropout = 0.20, activation='tanh', recurrent_activation='sigmoid'))

# Hidden Layer
model4.add(Dense(units=512 , activation = 'tanh'))
model4.add(Dense(units=256 , activation = 'tanh'))
model4.add(Dense(units=128 , activation = 'tanh'))
model4.add(Dropout(0.2))
model4.add(Dense(units=64 , activation = 'tanh'))
model4.add(Dropout(0.2))
model4.add(Dense(units=32 , activation = 'tanh'))
model4.add(Dropout(0.2))
model4.add(Dense(5, activation='softmax'))

# %%
from tensorflow.keras import callbacks
from tensorflow import keras

# Customer optimizer
adam_custom_lr = keras.optimizers.Adam(learning_rate=0.0001)

# Early Stopping Patient 15
early_stopping = callbacks.EarlyStopping(monitor ="val_accuracy", 
                                        patience = 20, 
                                        restore_best_weights = True)


model4.compile(loss='sparse_categorical_crossentropy', optimizer=adam_custom_lr, metrics=['accuracy'])

# %%
model4.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 300, 100)          1000000
#
#  lstm_6 (LSTM)               (None, 300, 512)          1255424
#
#  lstm_7 (LSTM)               (None, 256)               787456
#
#  dense_15 (Dense)            (None, 512)               131584
#
#  dense_16 (Dense)            (None, 256)               131328
#
#  dense_17 (Dense)            (None, 128)               32896
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_18 (Dense)            (None, 64)                8256
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_19 (Dense)            (None, 32)                2080
#
#  dropout_6 (Dropout)         (None, 32)                0
#
#  dense_20 (Dense)            (None, 5)                 165
#
# =================================================================
# Total params: 3,349,189
# Trainable params: 2,349,189
# Non-trainable params: 1,000,000
# _________________________________________________________________

# %%
epochs4 = 200
history4 = model4.fit(X_train, y_train, validation_split=0.1, epochs=epochs4, batch_size=128,  callbacks=[early_stopping])
# Out:
# Epoch 1/200
# 209/209 [==============================] - 28s 124ms/step - loss: 1.1396 - accuracy: 0.5452 - val_loss: 0.7087 - val_accuracy: 0.7369
# Epoch 2/200
# 209/209 [==============================] - 25s 119ms/step - loss: 0.7432 - accuracy: 0.7244 - val_loss: 0.6015 - val_accuracy: 0.7787
# Epoch 3/200
# 209/209 [==============================] - 25s 119ms/step - loss: 0.6791 - accuracy: 0.7493 - val_loss: 0.5677 - val_accuracy: 0.7875
# Epoch 4/200
# 209/209 [==============================] - 25s 119ms/step - loss: 0.6471 - accuracy: 0.7615 - val_loss: 0.5812 - val_accuracy: 0.7868
# Epoch 5/200
# 209/209 [==============================] - 25s 119ms/step - loss: 0.6210 - accuracy: 0.7710 - val_loss: 0.5134 - val_accuracy: 0.8178
# Epoch 6/200
# 209/209 [==============================] - 25s 120ms/step - loss: 0.6072 - accuracy: 0.7793 - val_loss: 0.5181 - val_accuracy: 0.8158
# Epoch 7/200
# 209/209 [==============================] - 25s 117ms/step - loss: 0.5930 - accuracy: 0.7867 - val_loss: 0.5115 - val_accuracy: 0.8154
# Epoch 8/200
# 209/209 [==============================] - 24s 116ms/step - loss: 0.5727 - accuracy: 0.7894 - val_loss: 0.4864 - val_accuracy: 0.8242
# Epoch 9/200
# 209/209 [==============================] - 24s 116ms/step - loss: 0.5640 - accuracy: 0.7949 - val_loss: 0.4838 - val_accuracy: 0.8255
# Epoch 10/200
# 209/209 [==============================] - 24s 116ms/step - loss: 0
200
# 209/209 [==============================] - 25s 118ms/step - loss: 0.2178 - accuracy: 0.9198 - val_loss: 0.2535 - val_accuracy: 0.9124
# Epoch 100/200
# 209/209 [==============================] - 25s 118ms/step - loss: 0.2098 - accuracy: 0.9219 - val_loss: 0.2662 - val_accuracy: 0.9087
# Epoch 101/200
# 209/209 [==============================] - 25s 118ms/step - loss: 0.2119 - accuracy: 0.9224 - val_loss: 0.2480 - val_accuracy: 0.9171
# Epoch 102/200
# 209/209 [==============================] - 25s 117ms/step - loss: 0.2075 - accuracy: 0.9234 - val_loss: 0.2522 - val_accuracy: 0.9124
# Epoch 103/200
# 209/209 [==============================] - 25s 118ms/step - loss: 0.2083 - accuracy: 0.9228 - val_loss: 0.2577 - val_accuracy: 0.9107
# Epoch 104/200
# 209/209 [==============================] - 25s 117ms/step - loss: 0.2089 - accuracy: 0.9225 - val_loss: 0.2569 - val_accuracy: 0.9114
# Epoch 105/200
# 209/209 [==============================] - 25s 117ms/step - loss: 0.2073 - accuracy: 0.9234 - val_loss: 0.2512 - val_accuracy: 0.9134
# Epoch 106/200
# 209/209 [==============================] - 25s 118ms/step - loss: 0.2077 - accuracy: 0.9247 - val_loss: 0.2570 - val_accuracy: 0.9114
# Epoch 107/200
# 209/209 [==============================] - 25s 117ms/step - loss: 0.2075 - accuracy: 0.9239 - val_loss: 0.2615 - val_accuracy: 0.9104
# Epoch 108/200
# 209/209 [==============================] - 25s 117ms/step - loss: 0.2086 - accuracy: 0.9240 - val_loss: 0.2570 - val_accuracy: 0.9141
# Epoch 109/200
# 209/209 [==============================] - 25s 117ms/step - loss: 0.2033 - accuracy: 0.9253 - val_loss: 0.2643 - val_accuracy: 0.9097
# Epoch 110/200
# 209/209 [==============================] - 25s 118ms/step - loss: 0.2026 - accuracy: 0.9251 - val_loss: 0.2639 - val_accuracy: 0.9118
# Epoch 111/200
# 209/209 [==============================] - 25s 118ms/step - loss: 0.2024 - accuracy: 0.9256 - val_loss: 0.2598 - val_accuracy: 0.9077
# Epoch 112/200
# 209/209 [==============================] - 25s 117ms/step - loss: 0.2039 - accuracy: 0.9243 - val_loss: 0.2548 - val_accuracy: 0.9087
# Epoch 113/200
# 209/209 [==============================] - 25s 119ms/step - loss: 0.1995 - accuracy: 0.9270 - val_loss: 0.2535 - val_accuracy: 0.9148
# Epoch 114/200
# 209/209 [==============================] - 25s 118ms/step - loss: 0.2018 - accuracy: 0.9266 - val_loss: 0.2723 - val_accuracy: 0.9104
# Epoch 115/200
# 209/209 [==============================] - 25s 117ms/step - loss: 0.1969 - accuracy: 0.9280 - val_loss: 0.2602 - val_accuracy: 0.9094
# Epoch 116/200
# 209/209 [==============================] - 25s 117ms/step - loss: 0.1983 - accuracy: 0.9272 - val_loss: 0.2506 - val_accuracy: 0.9144
# Epoch 117/200
# 209/209 [==============================] - 25s 118ms/step - loss: 0.1973 - accuracy: 0.9278 - val_loss: 0.2687 - val_accuracy: 0.9104
# Epoch 118/200
# 209/209 [==============================] - 24s 116ms/step - loss: 0.1968 - accuracy: 0.9258 - val_loss: 0.2559 - val_accuracy: 0.9111
# Epoch 119/200
# 209/209 [==============================] - 24s 116ms/step - loss: 0.1983 - accuracy: 0.9262 - val_loss: 0.2617 - val_accuracy: 0.9151
# Epoch 120/200
# 209/209 [==============================] - 24s 116ms/step - loss: 0.1941 - accuracy: 0.9292 - val_loss: 0.2498 - val_accuracy: 0.9151
# Epoch 121/200
# 209/209 [==============================] - 24s 116ms/step - loss: 0.1905 - accuracy: 0.9296 - val_loss: 0.2785 - val_accuracy: 0.9043

# %%
print("Accuracy of the model on Training Data is - " , model4.evaluate(X_train,y_train)[1]*100 , "%")
print("Accuracy of the model on Testing Data is - " , model4.evaluate(X_test,y_test)[1]*100 , "%")
# Out:
# 928/928 [==============================] - 28s 30ms/step - loss: 0.1737 - accuracy: 0.9361
# Accuracy of the model on Training Data is -  93.60533952713013 %
# 232/232 [==============================] - 7s 30ms/step - loss: 0.2342 - accuracy: 0.9229
# Accuracy of the model on Testing Data is -  92.29214191436768 %

# %%
# Evaluation matrix
import matplotlib.pyplot as plt

acc4 = history4.history['accuracy']
val_acc4 = history4.history['val_accuracy']
loss4 = history4.history['loss']
val_loss4 = history4.history['val_loss']

epochs = range(1, len(acc4)+1)

plt.plot(epochs, acc4, 'b', label='Train Accuracy')
plt.plot(epochs, val_acc4, 'r', label='Val Accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss4, 'b', label='Train Loss')
plt.plot(epochs, val_loss4, 'r', label='Val Loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
from sklearn.metrics import multilabel_confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

predict_x4 = model4.predict(X_test)
y_pred4 = np.argmax(predict_x4,axis=1)

cf4 = confusion_matrix(y_test, y_pred4)
cf4
# Out:
# array([[1442,    1,   11,    9,  116],
#        [   2, 1520,    8,    2,   34],
#        [   5,    1, 1493,    9,   33],
#        [   3,    2,   10, 1237,  209],
#        [  43,   16,    6,   52, 1157]], dtype=int64)

# %%
import seaborn as sns
x_axis_labels = ['religion', 'age', 'ethnicity', 'gender', 'not bullying']
y_axis_labels = ['religion', 'age', 'ethnicity', 'gender', 'not bullying']
ax = sns.heatmap(cf4, annot=True, cmap='Blues', fmt='g', xticklabels=x_axis_labels, yticklabels=y_axis_labels)

ax.set_title('Seaborn Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

## Display the visualization of the Confusion Matrix.
plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred4, target_names = ['religion', 'age', 'ethnicity', 'gender', 'not bullying']))
# Out:
#               precision    recall  f1-score   support
#
#     religion       0.96      0.91      0.94      1579
#          age       0.99      0.97      0.98      1566
#    ethnicity       0.98      0.97      0.97      1541
#       gender       0.94      0.85      0.89      1461
# not bullying       0.75      0.91      0.82      1274
#
#     accuracy                           0.92      7421
#    macro avg       0.92      0.92      0.92      7421
# weighted avg       0.93      0.92      0.92      7421

# %% [markdown]
# # The Fifth LSTM Tuning

# %%
from keras.layers import Dropout, BatchNormalization
model7 = Sequential()

#Non-trainable embeddidng layer
model7.add(Embedding(max_features, output_dim=embed_size, input_length=maxlen, trainable=False))

#LSTM 
model7.add(LSTM(units=512 , return_sequences = True, dropout = 0.40, activation='tanh', recurrent_activation='sigmoid'))
model7.add(LSTM(units=256, dropout = 0.40, activation='tanh', recurrent_activation='sigmoid'))
model7.add(BatchNormalization(momentum=0.95, epsilon=0.005))

# Hidden Layer
model7.add(Dense(units=512 , activation = 'tanh'))
model7.add(BatchNormalization(momentum=0.95, epsilon=0.005))
model7.add(Dense(units=256 , activation = 'tanh'))
model7.add(Dropout(0.5))
model7.add(Dense(units=128 , activation = 'tanh'))
model7.add(BatchNormalization(momentum=0.95, epsilon=0.005))
model7.add(Dense(units=64 , activation = 'tanh'))
model7.add(Dropout(0.5))
model7.add(Dense(units=32 , activation = 'tanh'))
model7.add(Dropout(0.5))
model7.add(Dense(5, activation='softmax'))

# %%
from tensorflow.keras import callbacks
from tensorflow import keras

# Customer optimizer
adam_custom_lr = keras.optimizers.Adam(learning_rate=0.0001)

# Early Stopping Patient 25
early_stopping = callbacks.EarlyStopping(monitor ="val_accuracy", 
                                        patience = 25, 
                                        restore_best_weights = True)


model7.compile(loss='sparse_categorical_crossentropy', optimizer=adam_custom_lr, metrics=['accuracy'])

# %%
model7.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_6 (Embedding)     (None, 300, 100)          1000000
#
#  lstm_11 (LSTM)              (None, 300, 512)          1255424
#
#  lstm_12 (LSTM)              (None, 256)               787456
#
#  batch_normalization (BatchN  (None, 256)              1024
#  ormalization)
#
#  dense_32 (Dense)            (None, 512)               131584
#
#  batch_normalization_1 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_33 (Dense)            (None, 256)               131328
#
#  dropout_13 (Dropout)        (None, 256)               0
#
#  dense_34 (Dense)            (None, 128)               32896
#
#  batch_normalization_2 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_35 (Dense)            (None, 64)                8256
#
#  dropout_14 (Dropout)        (None, 64)                0
#
#  dense_36 (Dense)            (None, 32)                2080
#
#  dropout_15 (Dropout)        (None, 32)                0
#
#  dense_37 (Dense)            (None, 5)                 165
#
# =================================================================
# Total params: 3,352,773
# Trainable params: 2,350,981
# Non-trainable params: 1,001,792
# _________________________________________________________________

# %%
epochs7 = 230
history7 = model7.fit(X_train, y_train, validation_split=0.15, epochs=epochs7, batch_size=128,  callbacks=[early_stopping])
# Out:
# Epoch 1/230
# 198/198 [==============================] - 28s 127ms/step - loss: 1.4334 - accuracy: 0.4539 - val_loss: 0.7469 - val_accuracy: 0.7375
# Epoch 2/230
# 198/198 [==============================] - 24s 122ms/step - loss: 1.1469 - accuracy: 0.5882 - val_loss: 0.7379 - val_accuracy: 0.7379
# Epoch 3/230
# 198/198 [==============================] - 24s 124ms/step - loss: 1.0752 - accuracy: 0.6207 - val_loss: 0.6849 - val_accuracy: 0.7521
# Epoch 4/230
# 198/198 [==============================] - 24s 123ms/step - loss: 1.0281 - accuracy: 0.6398 - val_loss: 0.6279 - val_accuracy: 0.7804
# Epoch 5/230
# 198/198 [==============================] - 24s 123ms/step - loss: 0.9977 - accuracy: 0.6517 - val_loss: 0.6793 - val_accuracy: 0.7572
# Epoch 6/230
# 198/198 [==============================] - 25s 124ms/step - loss: 0.9765 - accuracy: 0.6578 - val_loss: 0.7171 - val_accuracy: 0.7519
# Epoch 7/230
# 198/198 [==============================] - 25s 124ms/step - loss: 0.9443 - accuracy: 0.6712 - val_loss: 0.5995 - val_accuracy: 0.7828
# Epoch 8/230
# 198/198 [==============================] - 24s 123ms/step - loss: 0.9238 - accuracy: 0.6769 - val_loss: 0.5918 - val_accuracy: 0.7864
# Epoch 9/230
# 198/198 [==============================] - 24s 123ms/step - loss: 0.9113 - accuracy: 0.6819 - val_loss: 0.6075 - val_accuracy: 0.7858
# Epoch 10/230
# 198/198 [==============================] - 25s 127ms/step - loss: 0.8888 - accuracy: 0.6852 - val_loss: 0.5508 - val_accuracy: 0.7983
# Epoch 11/230
# 198/198 [==============================] - 24s 124ms/step - loss: 0.8545 - accuracy: 0.6992 - val_loss: 0.6345 - val_accuracy: 0.7694
# Epoch 12/230
# 198/198 [==============================] - 24s 123ms/step - loss: 0.8486 - accuracy: 0.7003 - val_loss: 0.5561 - val_accuracy: 0.7961
# Epoch 13/230
# 198/198 [==============================] - 24s 123ms/step - loss: 0.8449 - accuracy: 0.7024 - val_loss: 0.5479 - val_accuracy: 0.7961
# Epoch 14/230
# 198/198 [==============================] - 24s 123ms/step - loss: 0.8252 - accuracy: 0.7091 - val_loss: 0.5715 - val_accuracy: 0.7945
# Epoch 15/230
# 198/198 [==============================] - 24s 123ms/step - loss: 0.8058 - accuracy: 0.7140 - val_loss: 0.5465 - val_accuracy: 0.7995
# Epoch 16/230
# 198/198 [==============================] - 24s 123ms/step - loss: 0.7987 - accuracy: 0.7148 - val_loss: 0.6140 - val_accuracy: 0.7698
# Epoch 17/230
# 198/198 [==============================] - 24s 123ms/step - loss: 0.7829 - accuracy: 0.7245 - val_loss: 0.5435 - val_accuracy: 0.8037
# Epoch 18/230
# 198/198 [==============================] - 25s 124ms/step - loss: 0.7693 - accuracy: 0.7300 - val_loss: 0.5518 - val_accuracy: 0.7974
# Epoch 19/230
# 198/198 [==============================] - 25s 126ms/step - loss: 0.7637 - accuracy: 0.7282 - val_loss: 0.7447 - val_accuracy: 0.7312
# Epoch 20/230
# 198/198 [==============================] - 24s 124ms/step - loss: 0.7568 - accuracy: 0.7333 - val_loss: 0.5857 - val_accuracy: 0.7777
# Epoch 21/230
# 198/198 [==============================] - 25s 125ms/step - loss: 0
230
# 198/198 [==============================] - 24s 123ms/step - loss: 0.3423 - accuracy: 0.8837 - val_loss: 0.3162 - val_accuracy: 0.8850
# Epoch 109/230
# 198/198 [==============================] - 24s 123ms/step - loss: 0.3414 - accuracy: 0.8852 - val_loss: 0.3207 - val_accuracy: 0.8902
# Epoch 110/230
# 198/198 [==============================] - 24s 123ms/step - loss: 0.3342 - accuracy: 0.8877 - val_loss: 0.3478 - val_accuracy: 0.8794
# Epoch 111/230
# 198/198 [==============================] - 24s 123ms/step - loss: 0.3355 - accuracy: 0.8885 - val_loss: 0.4175 - val_accuracy: 0.8585
# Epoch 112/230
# 198/198 [==============================] - 24s 123ms/step - loss: 0.3412 - accuracy: 0.8838 - val_loss: 0.3010 - val_accuracy: 0.8958
# Epoch 113/230
# 198/198 [==============================] - 24s 123ms/step - loss: 0.3317 - accuracy: 0.8870 - val_loss: 0.3129 - val_accuracy: 0.8940
# Epoch 114/230
# 198/198 [==============================] - 24s 123ms/step - loss: 0.3331 - accuracy: 0.8877 - val_loss: 0.3543 - val_accuracy: 0.8886
# Epoch 115/230
# 198/198 [==============================] - 24s 123ms/step - loss: 0.3430 - accuracy: 0.8822 - val_loss: 0.3368 - val_accuracy: 0.8819
# Epoch 116/230
# 198/198 [==============================] - 24s 123ms/step - loss: 0.3407 - accuracy: 0.8858 - val_loss: 0.3296 - val_accuracy: 0.8861
# Epoch 117/230
# 198/198 [==============================] - 24s 123ms/step - loss: 0.3324 - accuracy: 0.8875 - val_loss: 0.3507 - val_accuracy: 0.8724
# Epoch 118/230
# 198/198 [==============================] - 24s 123ms/step - loss: 0.3276 - accuracy: 0.8901 - val_loss: 0.3028 - val_accuracy: 0.8956
# Epoch 119/230
# 198/198 [==============================] - 24s 123ms/step - loss: 0.3320 - accuracy: 0.8889 - val_loss: 0.3874 - val_accuracy: 0.8711
# Epoch 120/230
# 198/198 [==============================] - 24s 123ms/step - loss: 0.3362 - accuracy: 0.8860 - val_loss: 0.3103 - val_accuracy: 0.8909
# Epoch 121/230
# 198/198 [==============================] - 24s 123ms/step - loss: 0.3311 - accuracy: 0.8883 - val_loss: 0.3064 - val_accuracy: 0.8940
# Epoch 122/230
# 198/198 [==============================] - 24s 123ms/step - loss: 0.3257 - accuracy: 0.8894 - val_loss: 0.2919 - val_accuracy: 0.8951

# %%
print("Accuracy of the model on Training Data is - " , model7.evaluate(X_train,y_train)[1]*100 , "%")
print("Accuracy of the model on Testing Data is - " , model7.evaluate(X_test,y_test)[1]*100 , "%")
# Out:
# 928/928 [==============================] - 29s 31ms/step - loss: 0.2468 - accuracy: 0.9147
# Accuracy of the model on Training Data is -  91.46592020988464 %
# 232/232 [==============================] - 7s 31ms/step - loss: 0.2659 - accuracy: 0.9112
# Accuracy of the model on Testing Data is -  91.11979603767395 %

# %%
# Evaluation matrix
import matplotlib.pyplot as plt

acc7 = history7.history['accuracy']
val_acc7 = history7.history['val_accuracy']
loss7 = history7.history['loss']
val_loss7 = history7.history['val_loss']

epochs = range(1, len(acc7)+1)

plt.plot(epochs, acc7, 'b', label='Train Accuracy')
plt.plot(epochs, val_acc7, 'r', label='Val Accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss7, 'b', label='Train Loss')
plt.plot(epochs, val_loss7, 'r', label='Val Loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
from sklearn.metrics import multilabel_confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

predict_x7 = model7.predict(X_test)
y_pred7 = np.argmax(predict_x7,axis=1)

cf7 = confusion_matrix(y_test, y_pred7)
cf7
# Out:
# array([[1424,    2,    3,   11,  139],
#        [   2, 1534,    3,    1,   26],
#        [   7,    4, 1470,   13,   47],
#        [   3,    2,    2, 1204,  250],
#        [  40,   21,    1,   82, 1130]], dtype=int64)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred7, target_names = ['religion', 'age', 'ethnicity', 'gender', 'not bullying']))
# Out:
#               precision    recall  f1-score   support
#
#     religion       0.96      0.90      0.93      1579
#          age       0.98      0.98      0.98      1566
#    ethnicity       0.99      0.95      0.97      1541
#       gender       0.92      0.82      0.87      1461
# not bullying       0.71      0.89      0.79      1274
#
#     accuracy                           0.91      7421
#    macro avg       0.91      0.91      0.91      7421
# weighted avg       0.92      0.91      0.91      7421

# %% [markdown]
# ## Building BLSTM Model

# %%
from keras.models import Sequential
from keras.layers import Dense, Bidirectional, LSTM

# %%
model5 = Sequential()

#Non-trainable embeddidng layer
model5.add(Embedding(max_features, output_dim=embed_size, input_length=maxlen, trainable=False))

#BLSTM
model5.add(Bidirectional(LSTM(64, return_sequences=True), input_shape=(5, 10)))
model5.add(Bidirectional(LSTM(10)))

#Hidden Layer
model5.add(Dense(256, activation='relu'))
model5.add(Dense(128, activation='relu'))
model5.add(Dense(64, activation='relu'))
model5.add(Dense(32, activation='relu'))
model5.add(Dropout(0.3))

model5.add(Dense(6, activation='softmax'))

# %%
model5.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model5.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 300, 100)          1000000
#
#  bidirectional (Bidirectiona  (None, 300, 128)         84480
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 20)               11120
#  nal)
#
#  dense_21 (Dense)            (None, 256)               5376
#
#  dense_22 (Dense)            (None, 128)               32896
#
#  dense_23 (Dense)            (None, 64)                8256
#
#  dense_24 (Dense)            (None, 32)                2080
#
#  dropout_7 (Dropout)         (None, 32)                0
#
#  dense_25 (Dense)            (None, 6)                 198
#
# =================================================================
# Total params: 1,144,406
# Trainable params: 144,406
# Non-trainable params: 1,000,000
# _________________________________________________________________

# %%
epochs5 = 60
history5 = model5.fit(X_train, y_train, validation_split=0.1, epochs=epochs5, batch_size=128)
# Out:
# Epoch 1/60
# 209/209 [==============================] - 15s 60ms/step - loss: 1.3609 - accuracy: 0.3915 - val_loss: 0.9034 - val_accuracy: 0.6484
# Epoch 2/60
# 209/209 [==============================] - 12s 57ms/step - loss: 0.8159 - accuracy: 0.6931 - val_loss: 0.6558 - val_accuracy: 0.7508
# Epoch 3/60
# 209/209 [==============================] - 12s 57ms/step - loss: 0.6295 - accuracy: 0.7711 - val_loss: 0.5623 - val_accuracy: 0.7881
# Epoch 4/60
# 209/209 [==============================] - 12s 57ms/step - loss: 0.5457 - accuracy: 0.8023 - val_loss: 0.4959 - val_accuracy: 0.8201
# Epoch 5/60
# 209/209 [==============================] - 12s 56ms/step - loss: 0.4884 - accuracy: 0.8302 - val_loss: 0.5003 - val_accuracy: 0.8212
# Epoch 6/60
# 209/209 [==============================] - 12s 57ms/step - loss: 0.4619 - accuracy: 0.8415 - val_loss: 0.4439 - val_accuracy: 0.8390
# Epoch 7/60
# 209/209 [==============================] - 12s 57ms/step - loss: 0.4277 - accuracy: 0.8537 - val_loss: 0.4332 - val_accuracy: 0.8494
# Epoch 8/60
# 209/209 [==============================] - 12s 56ms/step - loss: 0.3998 - accuracy: 0.8645 - val_loss: 0.4303 - val_accuracy: 0.8575
# Epoch 9/60
# 209/209 [==============================] - 12s 56ms/step - loss: 0.3735 - accuracy: 0.8731 - val_loss: 0.4051 - val_accuracy: 0.8619
# Epoch 10/60
# 209/209 [==============================] - 12s 57ms/step - loss: 0.3592 - accuracy: 0.8789 - val_loss: 0.4013 - val_accuracy: 0.8629
# Epoch 11/60
# 209/209 [==============================] - 12s 57ms/step - loss: 0.3420 - accuracy: 0.8868 - val_loss: 0.3559 - val_accuracy: 0.8814
# Epoch 12/60
# 209/209 [==============================] - 12s 56ms/step - loss: 0.3238 - accuracy: 0.8912 - val_loss: 0.3603 - val_accuracy: 0.8717
# Epoch 13/60
# 209/209 [==============================] - 12s 56ms/step - loss: 0.3167 - accuracy: 0.8937 - val_loss: 0.3623 - val_accuracy: 0.8781
# Epoch 14/60
# 209/209 [==============================] - 12s 56ms/step - loss: 0.3028 - accuracy: 0.8991 - val_loss: 0.3369 - val_accuracy: 0.8841
# Epoch 15/60
# 209/209 [==============================] - 12s 57ms/step - loss: 0.3031 - accuracy: 0.8979 - val_loss: 0.3428 - val_accuracy: 0.8909
# Epoch 16/60
# 209/209 [==============================] - 12s 57ms/step - loss: 0.2910 - accuracy: 0.9015 - val_loss: 0.3497 - val_accuracy: 0.8858
# Epoch 17/60
# 209/209 [==============================] - 12s 56ms/step - loss: 0.2803 - accuracy: 0.9046 - val_loss: 0.3139 - val_accuracy: 0.8996
# Epoch 18/60
# 209/209 [==============================] - 12s 56ms/step - loss: 0.2679 - accuracy: 0.9081 - val_loss: 0.3102 - val_accuracy: 0.8986
# Epoch 19/60
# 209/209 [==============================] - 12s 56ms/step - loss: 0.2630 - accuracy: 0.9116 - val_loss: 0.3143 - val_accuracy: 0.8976
# Epoch 20/60
# 209/209 [==============================] - 12s 56ms/step - loss: 0.2582 - accuracy: 0.9118 - val_loss: 0.3070 - val_accuracy: 0.8959
# Epoch 21/60
# 209/209 [==============================] - 12s 56ms/step - loss: 0.2547 - accuracy: 0.9138 - val_loss: 0.3016 - val_accuracy: 0.9020
# Epoch 22/60
# 209/209 [==============================] - 12s 56ms/step - loss: 0.2659 - accuracy: 0.9093 - val_loss: 0.3015 - val_accuracy: 0.9003
# Epoch 23/60
# 209/209 [==============================] - 12s 56ms/step - loss: 0.2476 - accuracy: 0.9140 - val_loss: 0.3083 - val_accuracy: 0.8979
# Epoch 24/60
# 209/209 [==============================] - 12s 56ms/step - loss: 0.2397 - accuracy: 0.9190 - val_loss: 0.3228 - val_accuracy: 0.8979
# Epoch 25/60
# 209/209 [==============================] - 12s 56ms/step - loss: 0.2380 - accuracy: 0.9184 - val_loss: 0.3131 - val_accuracy: 0.8993
# Epoch 26/60
# 209/209 [==============================] - 12s 56ms/step - loss: 0.2326 - accuracy: 0.9214 - val_loss: 0.2974 - val_accuracy: 0.9070
# Epoch 27/60
# 209/209 [==============================] - 12s 56ms/step - loss: 0.2329 - accuracy: 0.9219 - val_loss: 0.2912 - val_accuracy: 0.9060
# Epoch 28/60
# 209/209 [==============================] - 12s 56ms/step - loss: 0.2233 - accuracy: 0.9237 - val_loss: 0.2862 - val_accuracy: 0.9087
# Epoch 29/60
# 209/209 [==============================] - 12s 57ms/step - loss: 0.2208 - accuracy: 0.9240 - val_loss: 0.3152 - val_accuracy: 0.9006
# Epoch 30/60
# 209/209 [==============================] - 12s 56ms/step - loss: 0.2221 - accuracy: 0.9252 - val_loss: 0.2930 - val_accuracy: 0.9064
# Epoch 31/60
# 209/209 [==============================] - 12s 56ms/step - loss: 0.2191 - accuracy: 0.9261 - val_loss: 0.2940 - val_accuracy: 0.9107
# Epoch 32/60
# 209/209 [==============================] - 12s 56ms/step - loss: 0.2081 - accuracy: 0.9292 - val_loss: 0.3075 - val_accuracy: 0.9087
# Epoch 33/60
# 209/209 [==============================] - 12s 56ms/step - loss: 0.2087 - accuracy: 0.9298 - val_loss: 0.3039 - val_accuracy: 0.9057
# Epoch 34/60
# 209/209 [==============================] - 12s 56ms/step - loss: 0.2073 - accuracy: 0.9299 - val_loss: 0.3054 - val_accuracy: 0.9114
# Epoch 35/60
# 209/209 [==============================] - 12s 56ms/step - loss: 0.2042 - accuracy: 0.9301 - val_loss: 0.3093 - val_accuracy: 0.9097
# Epoch 36/60
# 209/209 [==============================] - 12s 56ms/step - loss: 0.2015 - accuracy: 0.9309 - val_loss: 0.2900 - val_accuracy: 0.9050
# Epoch 37/60
# 209/209 [==============================] - 12s 56ms/step - loss: 0.2030 - accuracy: 0.9309 - val_loss: 0.3062 - val_accuracy: 0.9054
# Epoch 38/60
# 209/209 [==============================] - 12s 56ms/step - loss: 0.1950 - accuracy: 0.9327 - val_loss: 0.3451 - val_accuracy: 0.8949
# Epoch 39/60
# 209/209 [==============================] - 12s 56ms/step - loss: 0.1909 - accuracy: 0.9338 - val_loss: 0.2949 - val_accuracy: 0.9091
# Epoch 40/60
# 209/209 [==============================] - 12s 56ms/step - loss: 0.1859 - accuracy: 0.9366 - val_loss: 0.2982 - val_accuracy: 0.9121
# Epoch 41/60
# 209/209 [==============================] - 12s 56ms/step - loss: 0.1824 - accuracy: 0.9369 - val_loss: 0.3029 - val_accuracy: 0.9101
# Epoch 42/60
# 209/209 [==============================] - 12s 57ms/step - loss: 0.1833 - accuracy: 0.9367 - val_loss: 0.3119 - val_accuracy: 0.9094
# Epoch 43/60
# 209/209 [==============================] - 12s 56ms/step - loss: 0.1767 - accuracy: 0.9397 - val_loss: 0.3115 - val_accuracy: 0.9124
# Epoch 44/60
# 209/209 [==============================] - 12s 56ms/step - loss: 0.1956 - accuracy: 0.9340 - val_loss: 0.2994 - val_accuracy: 0.9070
# Epoch 45/60
# 209/209 [==============================] - 12s 56ms/step - loss: 0.1796 - accuracy: 0.9393 - val_loss: 0.2932 - val_accuracy: 0.9097
# Epoch 46/60
# 209/209 [==============================] - 12s 55ms/step - loss: 0.1672 - accuracy: 0.9400 - val_loss: 0.3183 - val_accuracy: 0.9134
# Epoch 47/60
# 209/209 [==============================] - 12s 55ms/step - loss: 0.1787 - accuracy: 0.9382 - val_loss: 0.2696 - val_accuracy: 0.9131
# Epoch 48/60
# 209/209 [==============================] - 12s 56ms/step - loss: 0.1635 - accuracy: 0.9433 - val_loss: 0.3135 - val_accuracy: 0.9134
# Epoch 49/60
# 209/209 [==============================] - 12s 55ms/step - loss: 0.1702 - accuracy: 0.9399 - val_loss: 0.3230 - val_accuracy: 0.9060
# Epoch 50/60
# 209/209 [==============================] - 12s 55ms/step - loss: 0.1656 - accuracy: 0.9428 - val_loss: 0.3207 - val_accuracy: 0.9134
# Epoch 51/60
# 209/209 [==============================] - 12s 55ms/step - loss: 0.1565 - accuracy: 0.9460 - val_loss: 0.3152 - val_accuracy: 0.9111
# Epoch 52/60
# 209/209 [==============================] - 12s 56ms/step - loss: 0.1611 - accuracy: 0.9425 - val_loss: 0.3100 - val_accuracy: 0.9128
# Epoch 53/60
# 209/209 [==============================] - 12s 57ms/step - loss: 0.1503 - accuracy: 0.9479 - val_loss: 0.3162 - val_accuracy: 0.9148
# Epoch 54/60
# 209/209 [==============================] - 12s 56ms/step - loss: 0.1589 - accuracy: 0.9457 - val_loss: 0.3106 - val_accuracy: 0.9111
# Epoch 55/60
# 209/209 [==============================] - 12s 56ms/step - loss: 0.1485 - accuracy: 0.9493 - val_loss: 0.3477 - val_accuracy: 0.9047
# Epoch 56/60
# 209/209 [==============================] - 12s 57ms/step - loss: 0.1487 - accuracy: 0.9486 - val_loss: 0.3529 - val_accuracy: 0.9087
# Epoch 57/60
# 209/209 [==============================] - 12s 56ms/step - loss: 0.1628 - accuracy: 0.9450 - val_loss: 0.3117 - val_accuracy: 0.9118
# Epoch 58/60
# 209/209 [==============================] - 12s 56ms/step - loss: 0.1409 - accuracy: 0.9511 - val_loss: 0.3510 - val_accuracy: 0.9080
# Epoch 59/60
# 209/209 [==============================] - 12s 56ms/step - loss: 0.1538 - accuracy: 0.9471 - val_loss: 0.3023 - val_accuracy: 0.9080
# Epoch 60/60
# 209/209 [==============================] - 12s 56ms/step - loss: 0.1332 - accuracy: 0.9539 - val_loss: 0.3512 - val_accuracy: 0.9111

# %%
print("Accuracy of the model on Training Data is - " , model5.evaluate(X_train,y_train)[1]*100 , "%")
print("Accuracy of the model on Testing Data is - " , model5.evaluate(X_test,y_test)[1]*100 , "%")
# Out:
# 928/928 [==============================] - 19s 21ms/step - loss: 0.1414 - accuracy: 0.9531
# Accuracy of the model on Training Data is -  95.31350135803223 %
# 232/232 [==============================] - 5s 21ms/step - loss: 0.3180 - accuracy: 0.9189
# Accuracy of the model on Testing Data is -  91.88788533210754 %

# %%
# Evaluation matrix
import matplotlib.pyplot as plt

acc5 = history5.history['accuracy']
val_acc5 = history5.history['val_accuracy']
loss5 = history5.history['loss']
val_loss5 = history5.history['val_loss']

epochs = range(1, len(acc5)+1)

plt.plot(epochs, acc5, 'b', label='Train Accuracy')
plt.plot(epochs, val_acc5, 'r', label='Val Accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss5, 'b', label='Train Loss')
plt.plot(epochs, val_loss5, 'r', label='Val Loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
from sklearn.metrics import multilabel_confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

predict_x5 = model5.predict(X_test)
y_pred5 = np.argmax(predict_x5,axis=1)

cf5 = confusion_matrix(y_test, y_pred5)
cf5
# Out:
# array([[1478,    2,    8,   11,   80],
#        [   2, 1529,    6,    1,   28],
#        [   8,    4, 1498,    8,   23],
#        [   9,    4,    7, 1224,  217],
#        [  81,   22,   12,   69, 1090]], dtype=int64)

# %%
import seaborn as sns
x_axis_labels = ['religion', 'age', 'ethnicity', 'gender', 'not bullying']
y_axis_labels = ['religion', 'age', 'ethnicity', 'gender', 'not bullying']
ax = sns.heatmap(cf5, annot=True, cmap='Blues', fmt='g', xticklabels=x_axis_labels, yticklabels=y_axis_labels)

ax.set_title('Seaborn Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

## Display the visualization of the Confusion Matrix.
plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred5, target_names = ['religion', 'age', 'ethnicity', 'gender', 'not bullying']))
# Out:
#               precision    recall  f1-score   support
#
#     religion       0.94      0.94      0.94      1579
#          age       0.98      0.98      0.98      1566
#    ethnicity       0.98      0.97      0.98      1541
#       gender       0.93      0.84      0.88      1461
# not bullying       0.76      0.86      0.80      1274
#
#     accuracy                           0.92      7421
#    macro avg       0.92      0.92      0.92      7421
# weighted avg       0.92      0.92      0.92      7421

# %% [markdown]
# ## Second BLSTM Model

# %% [markdown]
# Lower batch size =32, early stopping patience 30, total epochs 250, larger unit of BiLSTM, more deep learning layer, with more dropout, adma learnign rate 0.0001

# %%
model6 = Sequential()

#Non-trainable embeddidng layer
model6.add(Embedding(max_features, output_dim=embed_size, input_length=maxlen, trainable=False))

#BLSTM
model6.add(Bidirectional(LSTM(256, return_sequences=True), input_shape=(5, 10)))
model6.add(Bidirectional(LSTM(128)))
model6.add(BatchNormalization())

#Hidden Layer
model6.add(Dense(512, activation='relu'))
model6.add(Dropout(0.5))
model6.add(Dense(256, activation='relu'))
model6.add(Dropout(0.2))
model6.add(Dense(128, activation='relu'))
model6.add(Dropout(0.3))
model6.add(Dense(64, activation='relu'))
model6.add(Dropout(0.3))
model6.add(Dense(32, activation='relu'))
model6.add(Dropout(0.3))

model6.add(Dense(6, activation='softmax'))

# %%
from tensorflow.keras import callbacks

# Customer optimizer
adam_custom_lr = keras.optimizers.Adam(learning_rate=0.0001)

# Early Stopping Patient 25
early_stopping = callbacks.EarlyStopping(monitor ="val_loss", 
                                        patience = 25, 
                                        restore_best_weights = True)


model6.compile(loss='sparse_categorical_crossentropy', optimizer=adam_custom_lr, metrics=['accuracy'])

# %%
model6.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_9 (Embedding)     (None, 300, 100)          1000000
#
#  bidirectional_7 (Bidirectio  (None, 300, 512)         731136
#  nal)
#
#  bidirectional_8 (Bidirectio  (None, 256)              656384
#  nal)
#
#  batch_normalization_3 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dense_44 (Dense)            (None, 512)               131584
#
#  dropout_21 (Dropout)        (None, 512)               0
#
#  dense_45 (Dense)            (None, 256)               131328
#
#  dropout_22 (Dropout)        (None, 256)               0
#
#  dense_46 (Dense)            (None, 128)               32896
#
#  dropout_23 (Dropout)        (None, 128)               0
#
#  dense_47 (Dense)            (None, 64)                8256
#
#  dropout_24 (Dropout)        (None, 64)                0
#
#  dense_48 (Dense)            (None, 32)                2080
#
#  dropout_25 (Dropout)        (None, 32)                0
#
#  dense_49 (Dense)            (None, 6)                 198
#
# =================================================================
# Total params: 2,694,886
# Trainable params: 1,694,374
# Non-trainable params: 1,000,512
# _________________________________________________________________

# %%
epochs6 = 250
history6 = model6.fit(X_train, y_train, validation_split=0.15, epochs=epochs6, batch_size=32,  callbacks=[early_stopping])
# Out:
# Epoch 1/250
# 789/789 [==============================] - 68s 81ms/step - loss: 1.2368 - accuracy: 0.5028 - val_loss: 1.8161 - val_accuracy: 0.4799
# Epoch 2/250
# 789/789 [==============================] - 64s 81ms/step - loss: 0.7306 - accuracy: 0.7550 - val_loss: 0.9621 - val_accuracy: 0.6852
# Epoch 3/250
# 789/789 [==============================] - 64s 81ms/step - loss: 0.6534 - accuracy: 0.7852 - val_loss: 1.0010 - val_accuracy: 0.6843
# Epoch 4/250
# 789/789 [==============================] - 64s 81ms/step - loss: 0.6238 - accuracy: 0.7956 - val_loss: 1.3762 - val_accuracy: 0.6191
# Epoch 5/250
# 789/789 [==============================] - 64s 81ms/step - loss: 0.5970 - accuracy: 0.8009 - val_loss: 0.9707 - val_accuracy: 0.6932
# Epoch 6/250
# 789/789 [==============================] - 64s 81ms/step - loss: 0.5716 - accuracy: 0.8065 - val_loss: 0.6681 - val_accuracy: 0.7662
# Epoch 7/250
# 789/789 [==============================] - 64s 81ms/step - loss: 0.5491 - accuracy: 0.8156 - val_loss: 0.5161 - val_accuracy: 0.8165
# Epoch 8/250
# 789/789 [==============================] - 64s 81ms/step - loss: 0.5318 - accuracy: 0.8223 - val_loss: 0.5072 - val_accuracy: 0.8152
# Epoch 9/250
# 789/789 [==============================] - 64s 81ms/step - loss: 0.5097 - accuracy: 0.8283 - val_loss: 0.5569 - val_accuracy: 0.8075
# Epoch 10/250
# 789/789 [==============================] - 63s 79ms/step - loss: 0.4880 - accuracy: 0.8343 - val_loss: 0.4526 - val_accuracy: 0.8408
# Epoch 11/250
# 789/789 [==============================] - 63s 80ms/step - loss: 0.4797 - accuracy: 0.8378 - val_loss: 0.6501 - val_accuracy: 0.7853
# Epoch 12/250
# 789/789 [==============================] - 64s 81ms/step - loss: 0.4600 - accuracy: 0.8452 - val_loss: 0.5334 - val_accuracy: 0.8082
# Epoch 13/250
# 789/789 [==============================] - 64s 81ms/step - loss: 0.4461 - accuracy: 0.8466 - val_loss: 0.4308 - val_accuracy: 0.8446
# Epoch 14/250
# 789/789 [==============================] - 64s 81ms/step - loss: 0.4357 - accuracy: 0.8532 - val_loss: 0.4189 - val_accuracy: 0.8491
# Epoch 15/250
# 789/789 [==============================] - 64s 81ms/step - loss: 0.4205 - accuracy: 0.8573 - val_loss: 0.5123 - val_accuracy: 0.8174
# Epoch 16/250
# 789/789 [==============================] - 64s 81ms/step - loss: 0.4103 - accuracy: 0.8623 - val_loss: 0.4069 - val_accuracy: 0.8531
# Epoch 17/250
# 789/789 [==============================] - 63s 80ms/step - loss: 0.3969 - accuracy: 0.8669 - val_loss: 0.3927 - val_accuracy: 0.8545
# Epoch 18/250
# 789/789 [==============================] - 64s 81ms/step - loss: 0.3881 - accuracy: 0.8674 - val_loss: 0.3865 - val_accuracy: 0.8623
# Epoch 19/250
# 789/789 [==============================] - 64s 81ms/step - loss: 0.3729 - accuracy: 0.8727 - val_loss: 0.4736 - val_accuracy: 0.8352
# Epoch 20/250
# 789/789 [==============================] - 64s 81ms/step - loss: 0.3675 - accuracy: 0.8743 - val_loss: 0.4429 - val_accuracy: 0.8462
# Epoch 21/250
# 789/789 [==============================] - 64s 81ms/step - loss: 0.3603 - accuracy: 0.8789 - val_loss: 0.4648 - val_accuracy: 0.8430
# Epoch 22/250
# 789/789 [==============================] - 63s 80ms/step - loss: 0.3521 - accuracy: 0.8784 - val_loss: 0.4232 - val_accuracy: 0.8570
# Epoch 23/250
# 789/789 [==============================] - 64s 81ms/step - loss: 0.3418 - accuracy: 0.8809 - val_loss: 0.4164 - val_accuracy: 0.8617
# Epoch 24/250
# 789/789 [==============================] - 64s 81ms/step - loss: 0.3391 - accuracy: 0.8827 - val_loss: 0.3926 - val_accuracy: 0.8628
# Epoch 25/250
# 789/789 [==============================] - 64s 81ms/step - loss: 0.3263 - accuracy: 0.8872 - val_loss: 0.5643 - val_accuracy: 0.8226
# Epoch 26/250
# 789/789 [==============================] - 64s 81ms/step - loss: 0.3202 - accuracy: 0.8890 - val_loss: 0.3923 - val_accuracy: 0.8635
# Epoch 27/250
# 789/789 [==============================] - 64s 81ms/step - loss: 0.3152 - accuracy: 0.8938 - val_loss: 0.4675 - val_accuracy: 0.8428
# Epoch 28/250
# 789/789 [==============================] - 63s 80ms/step - loss: 0.3066 - accuracy: 0.8935 - val_loss: 1.2129 - val_accuracy: 0.6964
# Epoch 29/250
# 789/789 [==============================] - 63s 80ms/step - loss: 0.3022 - accuracy: 0.8925 - val_loss: 0.4961 - val_accuracy: 0.8455
# Epoch 30/250
# 789/789 [==============================] - 63s 80ms/step - loss: 0.2922 - accuracy: 0.8987 - val_loss: 0.3669 - val_accuracy: 0.8718
# Epoch 31/250
# 789/789 [==============================] - 64s 81ms/step - loss: 0.2907 - accuracy: 0.8983 - val_loss: 0.3975 - val_accuracy: 0.8729
# Epoch 32/250
# 789/789 [==============================] - 63s 80ms/step - loss: 0.2913 - accuracy: 0.8982 - val_loss: 0.3631 - val_accuracy: 0.8814
# Epoch 33/250
# 789/789 [==============================] - 62s 79ms/step - loss: 0.2810 - accuracy: 0.9009 - val_loss: 0.3960 - val_accuracy: 0.8682
# Epoch 34/250
# 789/789 [==============================] - 63s 80ms/step - loss: 0.2782 - accuracy: 0.9032 - val_loss: 0.4154 - val_accuracy: 0.8612
# Epoch 35/250
# 789/789 [==============================] - 63s 80ms/step - loss: 0.2690 - accuracy: 0.9067 - val_loss: 0.4252 - val_accuracy: 0.8421
# Epoch 36/250
# 789/789 [==============================] - 64s 80ms/step - loss: 0.2647 - accuracy: 0.9076 - val_loss: 0.3913 - val_accuracy: 0.8749
# Epoch 37/250
# 789/789 [==============================] - 63s 80ms/step - loss: 0.2674 - accuracy: 0.9075 - val_loss: 0.3833 - val_accuracy: 0.8653
# Epoch 38/250
# 789/789 [==============================] - 63s 80ms/step - loss: 0.2588 - accuracy: 0.9097 - val_loss: 0.4112 - val_accuracy: 0.8556
# Epoch 39/250
# 789/789 [==============================] - 63s 80ms/step - loss: 0.2525 - accuracy: 0.9115 - val_loss: 0.4756 - val_accuracy: 0.8439
# Epoch 40/250
# 789/789 [==============================] - 63s 80ms/step - loss: 0.2540 - accuracy: 0.9116 - val_loss: 0.4005 - val_accuracy: 0.8684
# Epoch 41/250
# 789/789 [==============================] - 62s 79ms/step - loss: 0.2444 - accuracy: 0.9147 - val_loss: 0.5397 - val_accuracy: 0.8296
# Epoch 42/250
# 789/789 [==============================] - 62s 79ms/step - loss: 0.2537 - accuracy: 0.9134 - val_loss: 0.4262 - val_accuracy: 0.8599
# Epoch 43/250
# 789/789 [==============================] - 63s 80ms/step - loss: 0.2400 - accuracy: 0.9169 - val_loss: 0.5402 - val_accuracy: 0.8278
# Epoch 44/250
# 789/789 [==============================] - 62s 79ms/step - loss: 0.2325 - accuracy: 0.9179 - val_loss: 0.3918 - val_accuracy: 0.8713
# Epoch 45/250
# 789/789 [==============================] - 63s 79ms/step - loss: 0.2357 - accuracy: 0.9181 - val_loss: 0.4302 - val_accuracy: 0.8567
# Epoch 46/250
# 789/789 [==============================] - 63s 80ms/step - loss: 0.2381 - accuracy: 0.9179 - val_loss: 0.3367 - val_accuracy: 0.8861
# Epoch 47/250
# 789/789 [==============================] - 63s 80ms/step - loss: 0.2321 - accuracy: 0.9197 - val_loss: 0.4714 - val_accuracy: 0.8531
# Epoch 48/250
# 789/789 [==============================] - 63s 80ms/step - loss: 0.2276 - accuracy: 0.9225 - val_loss: 0.3869 - val_accuracy: 0.8821
# Epoch 49/250
# 789/789 [==============================] - 63s 80ms/step - loss: 0.2294 - accuracy: 0.9202 - val_loss: 0.4915 - val_accuracy: 0.8336
# Epoch 50/250
# 789/789 [==============================] - 63s 79ms/step - loss: 0.2131 - accuracy: 0.9231 - val_loss: 0.3885 - val_accuracy: 0.8713
# Epoch 51/250
# 789/789 [==============================] - 63s 80ms/step - loss: 0.2150 - accuracy: 0.9269 - val_loss: 0.8326 - val_accuracy: 0.7810
# Epoch 52/250
# 789/789 [==============================] - 63s 80ms/step - loss: 0.2193 - accuracy: 0.9251 - val_loss: 0.3901 - val_accuracy: 0.8650
# Epoch 53/250
# 789/789 [==============================] - 63s 80ms/step - loss: 0.2089 - accuracy: 0.9279 - val_loss: 0.4945 - val_accuracy: 0.8446
# Epoch 54/250
# 789/789 [==============================] - 62s 79ms/step - loss: 0.2095 - accuracy: 0.9275 - val_loss: 0.4518 - val_accuracy: 0.8583
# Epoch 55/250
# 789/789 [==============================] - 63s 80ms/step - loss: 0.2117 - accuracy: 0.9267 - val_loss: 0.4246 - val_accuracy: 0.8711
# Epoch 56/250
# 789/789 [==============================] - 63s 80ms/step - loss: 0.2058 - accuracy: 0.9283 - val_loss: 0.5247 - val_accuracy: 0.8372
# Epoch 57/250
# 789/789 [==============================] - 64s 81ms/step - loss: 0.2022 - accuracy: 0.9296 - val_loss: 0.3949 - val_accuracy: 0.8832
# Epoch 58/250
# 789/789 [==============================] - 63s 80ms/step - loss: 0.1984 - accuracy: 0.9325 - val_loss: 0.5245 - val_accuracy: 0.8442
# Epoch 59/250
# 789/789 [==============================] - 63s 80ms/step - loss: 0.1948 - accuracy: 0.9318 - val_loss: 0.9022 - val_accuracy: 0.7757
# Epoch 60/250
# 789/789 [==============================] - 63s 80ms/step - loss: 0.1950 - accuracy: 0.9325 - val_loss: 0.4727 - val_accuracy: 0.8619
# Epoch 61/250
# 789/789 [==============================] - 63s 80ms/step - loss: 0.1945 - accuracy: 0.9312 - val_loss: 0.4398 - val_accuracy: 0.8758
# Epoch 62/250
# 789/789 [==============================] - 64s 81ms/step - loss: 0.1870 - accuracy: 0.9354 - val_loss: 0.5036 - val_accuracy: 0.8754
# Epoch 63/250
# 789/789 [==============================] - 64s 81ms/step - loss: 0.1936 - accuracy: 0.9334 - val_loss: 0.4065 - val_accuracy: 0.8857
# Epoch 64/250
# 789/789 [==============================] - 63s 80ms/step - loss: 0.1836 - accuracy: 0.9360 - val_loss: 0.4251 - val_accuracy: 0.8803
# Epoch 65/250
# 789/789 [==============================] - 64s 80ms/step - loss: 0.1844 - accuracy: 0.9364 - val_loss: 0.3881 - val_accuracy: 0.8875
# Epoch 66/250
# 789/789 [==============================] - 64s 81ms/step - loss: 0.1770 - accuracy: 0.9379 - val_loss: 0.3458 - val_accuracy: 0.8839
# Epoch 67/250
# 789/789 [==============================] - 63s 80ms/step - loss: 0.1748 - accuracy: 0.9387 - val_loss: 0.4275 - val_accuracy: 0.8673
# Epoch 68/250
# 789/789 [==============================] - 63s 80ms/step - loss: 0.1811 - accuracy: 0.9371 - val_loss: 0.3519 - val_accuracy: 0.8866
# Epoch 69/250
# 789/789 [==============================] - 63s 80ms/step - loss: 0.1704 - accuracy: 0.9417 - val_loss: 0.3780 - val_accuracy: 0.8808
# Epoch 70/250
# 789/789 [==============================] - 63s 80ms/step - loss: 0.1692 - accuracy: 0.9417 - val_loss: 0.4524 - val_accuracy: 0.8740
# Epoch 71/250
# 789/789 [==============================] - 63s 80ms/step - loss: 0.1644 - accuracy: 0.9416 - val_loss: 0.6331 - val_accuracy: 0.8181

# %%
print("Accuracy of the model on Training Data is - " , model6.evaluate(X_train,y_train)[1]*100 , "%")
print("Accuracy of the model on Testing Data is - " , model6.evaluate(X_test,y_test)[1]*100 , "%")
# Out:
# 928/928 [==============================] - 29s 31ms/step - loss: 0.2252 - accuracy: 0.9194
# Accuracy of the model on Training Data is -  91.94097518920898 %
# 232/232 [==============================] - 7s 31ms/step - loss: 0.3389 - accuracy: 0.8981
# Accuracy of the model on Testing Data is -  89.81269598007202 %

# %%
# Evaluation matrix
import matplotlib.pyplot as plt

acc6 = history6.history['accuracy']
val_acc6 = history6.history['val_accuracy']
loss6 = history6.history['loss']
val_loss6 = history6.history['val_loss']

epochs = range(1, len(acc6)+1)

plt.plot(epochs, acc6, 'b', label='Train Accuracy')
plt.plot(epochs, val_acc6, 'r', label='Val Accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss6, 'b', label='Train Loss')
plt.plot(epochs, val_loss5, 'r', label='Val Loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 4>()
#       1 # Evaluation matrix
#       2 import matplotlib.pyplot as plt
# ----> 4 acc6 = history6.history['accuracy']
#       5 val_acc6 = history6.history['val_accuracy']
#       6 loss6 = history6.history['loss']
#
# NameError: name 'history6' is not defined

# %%
from sklearn.metrics import multilabel_confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

predict_x6 = model6.predict(X_test)
y_pred6 = np.argmax(predict_x6,axis=1)

cf6 = confusion_matrix(y_test, y_pred6)
cf6

# %%
import seaborn as sns
x_axis_labels = ['religion', 'age', 'ethnicity', 'gender', 'not bullying']
y_axis_labels = ['religion', 'age', 'ethnicity', 'gender', 'not bullying']
ax = sns.heatmap(cf6, annot=True, cmap='Blues', fmt='g', xticklabels=x_axis_labels, yticklabels=y_axis_labels)

ax.set_title('Seaborn Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

## Display the visualization of the Confusion Matrix.
plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred6, target_names = ['religion', 'age', 'ethnicity', 'gender', 'not bullying']))
